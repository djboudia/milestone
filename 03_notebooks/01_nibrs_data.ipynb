# %% [markdown]
# <style>div.container { width: 100% }</style>
# <img style="float:left;  vertical-align:text-bottom;" height="65" width="172" src="../06_assets/NIBRS Logo 500.jpg" />
# <div style="float:right; vertical-align:text-bottom;"><h2>NIBRS DATA</h2></div>

# %% [markdown]
# This notebook shows how to obtain NIBRS datasets for 2010 -> 2019 and the NIBRS data cleaning /
# manipulation steps required before joining sports data.
#
# &nbsp;
#
# ### Download Data
#
# The first step is to download the datasets and store them in an appropriate directory structure. \
# These were downloaded manually from the [NIBRS Crime Data Explorer website](https://crime-data-explorer.fr.cloud.gov/pages/downloads) website. \
# \
# On the website:
#  1. Navigate to the section labeled "Crime Incident-Based Data by State"
#  1. Specify 'Michigan' as state name and add the needed year, e.g. '2010' (repeat for each year needed)
#  1. Click "Download" - this downloads that year's dataset to the location on your harddrive specified by browser settings (usually folder named "Download")
#  1. Once the datasets are downloaded, and you're able to navigate to them locally, you'll want to move them to a single folder under your project folder
#    - The project folder **must** have a parent folder titled **'Data'** and a subfolder titled **'NIBRS'** (e.g. /Project/Data/NIBRS)
#  1. Proceed to the following code steps which will import necessary libraries and extract files of interest into 4 separate DataFrame objects

# %% [markdown]
# [INCIDENTS](#incidents)\
# [AGENCIES](#agencies)\
# [OFFENSE TYPE](#offense_type)\
# [OFFENSES](#offenses)

# %%
# The following libraries will be used for the NIBRS data manipulation
# The OS library is native to Python and should already be available if you're running conda
# To install pandas, you can uncomment the following line(s)
# Please note that you can either use a utility called "pip" or Conda if you're using the anaconda data science distribution

# Uncomment of the following two lines to install pandas (only if you're not able to run pandas)
# !pip install pandas
# !conda install pandas

import os
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns',100)

# %%
# Initialize each topic's list of dataframes (ie each list will store a dataframe corresponding to the year for that type of data
incident_lst = []
agencies_lst = []
offenses_lst = []
offense_type_lst = []


for folder in os.listdir('../00_nibrs_downloads/'):
    filepath = f'../00_nibrs_downloads/{folder}'
    
    if os.path.isdir(filepath):
        print(filepath)
        for file in os.listdir(filepath):
            if file == 'nibrs_incident.csv' or file == 'NIBRS_incident.csv':
                print(f'found incident file: {file} in', filepath)
                incident_lst.append(pd.read_csv(filepath + "/" + file))
                
            if file == 'nibrs_offense.csv' or file =='NIBRS_OFFENSE.csv':
                print('found offense file in', filepath)
                temp = pd.read_csv(filepath + "/" + file)
                if 'DATA_YEAR' not in temp.columns:
                    temp.insert(0,'DATA_YEAR',filepath.split('-')[1])
                offenses_lst.append(temp)
                
            if file == 'cde_agencies.csv' or file == 'agencies.csv':
                print('found agency file in', filepath)
                temp = pd.read_csv(filepath + "/" + file)
                temp['DATA_YEAR'] = filepath.split('-')[1]
                agencies_lst.append(temp)
                
            if file == 'nibrs_offense_type.csv' or file == 'NIBRS_OFFENSE_TYPE.csv':
                print('found offense_type file in', filepath)
                temp = pd.read_csv(filepath + "/" + file)
                temp['DATA_YEAR'] = filepath.split('-')[1]
                offense_type_lst.append(temp)
        print('\n')
# Out:
# ../00_nibrs_downloads/MI-2009
# found agency file in ../00_nibrs_downloads/MI-2009
# found incident file: nibrs_incident.csv in ../00_nibrs_downloads/MI-2009
# found offense file in ../00_nibrs_downloads/MI-2009
# found offense_type file in ../00_nibrs_downloads/MI-2009
#
#
# ../00_nibrs_downloads/MI-2010
# found agency file in ../00_nibrs_downloads/MI-2010
# found incident file: nibrs_incident.csv in ../00_nibrs_downloads/MI-2010
# C:\Users\RJ\AppData\Roaming\Python\Python38\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# found offense file in ../00_nibrs_downloads/MI-2010
# found offense_type file in ../00_nibrs_downloads/MI-2010
#
#
# ../00_nibrs_downloads/MI-2011
# found agency file in ../00_nibrs_downloads/MI-2011
# found incident file: nibrs_incident.csv in ../00_nibrs_downloads/MI-2011
# found offense file in ../00_nibrs_downloads/MI-2011
# found offense_type file in ../00_nibrs_downloads/MI-2011
#
#
# ../00_nibrs_downloads/MI-2012
# found agency file in ../00_nibrs_downloads/MI-2012
# found incident file: nibrs_incident.csv in ../00_nibrs_downloads/MI-2012
# found offense file in ../00_nibrs_downloads/MI-2012
# found offense_type file in ../00_nibrs_downloads/MI-2012
#
#
# ../00_nibrs_downloads/MI-2013
# found agency file in ../00_nibrs_downloads/MI-2013
# found incident file: nibrs_incident.csv in ../00_nibrs_downloads/MI-2013
# found offense file in ../00_nibrs_downloads/MI-2013
# found offense_type file in ../00_nibrs_downloads/MI-2013
#
#
# ../00_nibrs_downloads/MI-2014
# found agency file in ../00_nibrs_downloads/MI-2014
# found incident file: nibrs_incident.csv in ../00_nibrs_downloads/MI-2014
# found offense file in ../00_nibrs_downloads/MI-2014
# found offense_type file in ../00_nibrs_downloads/MI-2014
#
#
# ../00_nibrs_downloads/MI-2015
# found agency file in ../00_nibrs_downloads/MI-2015
# found incident file: nibrs_incident.csv in ../00_nibrs_downloads/MI-2015
# found offense file in ../00_nibrs_downloads/MI-2015
# found offense_type file in ../00_nibrs_downloads/MI-2015
#
#
# ../00_nibrs_downloads/MI-2016
# found agency file in ../00_nibrs_downloads/MI-2016
# found incident file: nibrs_incident.csv in ../00_nibrs_downloads/MI-2016
# found offense file in ../00_nibrs_downloads/MI-2016
# found offense_type file in ../00_nibrs_downloads/MI-2016
#
#
# ../00_nibrs_downloads/MI-2017
# found agency file in ../00_nibrs_downloads/MI-2017
# found incident file: NIBRS_incident.csv in ../00_nibrs_downloads/MI-2017
# found offense file in ../00_nibrs_downloads/MI-2017
# found offense_type file in ../00_nibrs_downloads/MI-2017
#
#
# ../00_nibrs_downloads/MI-2018
# found agency file in ../00_nibrs_downloads/MI-2018
# found incident file: NIBRS_incident.csv in ../00_nibrs_downloads/MI-2018
# found offense file in ../00_nibrs_downloads/MI-2018
# found offense_type file in ../00_nibrs_downloads/MI-2018
#
#
# ../00_nibrs_downloads/MI-2019
# found agency file in ../00_nibrs_downloads/MI-2019
# found incident file: NIBRS_incident.csv in ../00_nibrs_downloads/MI-2019
# found offense file in ../00_nibrs_downloads/MI-2019
# found offense_type file in ../00_nibrs_downloads/MI-2019

# %% [markdown]
# ---
#
# &nbsp;
#
# ## DATA CLEANING
#
# Now we need to look at each of the 4 list of 10 dataframes and compare how they are set up. \
# We'll start by looking at the columns of incidents frames. \
# We need to evaluate whether they are formatted the same way across the years and if they contain the same data.

# %% [markdown]
# <a id='incidents'></a>

# %% [markdown]
# &nbsp;
#
# ## INCIDENTS

# %%
for frame in incident_lst:
    print(frame.dtypes, len(frame.columns), '\n')
# Out:
# agency_id                int64
# incident_id              int64
# nibrs_month_id           int64
# incident_number          int64
# cargo_theft_flag       float64
# submission_date        float64
# incident_date           object
# report_date_flag        object
# incident_hour          float64
# cleared_except_id        int64
# cleared_except_date     object
# incident_status          int64
# data_home               object
# ddocname                object
# orig_format            float64
# ff_line_number         float64
# did                    float64
# dtype: object 17
#
# agency_id                int64
# incident_id              int64
# nibrs_month_id           int64
# incident_number          int64
# cargo_theft_flag       float64
# submission_date        float64
# incident_date           object
# report_date_flag        object
# incident_hour          float64
# cleared_except_id        int64
# cleared_except_date     object
# incident_status          int64
# data_home               object
# ddocname                object
# orig_format            float64
# ff_line_number         float64
# did                    float64
# dtype: object 17
#
# agency_id                int64
# incident_id              int64
# nibrs_month_id           int64
# incident_number          int64
# cargo_theft_flag        object
# submission_date        float64
# incident_date           object
# report_date_flag        object
# incident_hour          float64
# cleared_except_id        int64
# cleared_except_date     object
# incident_status          int64
# data_home               object
# ddocname                object
# orig_format            float64
# ff_line_number         float64
# did                    float64
# dtype: object 17
#
# agency_id                int64
# incident_id              int64
# nibrs_month_id           int64
# incident_number          int64
# cargo_theft_flag        object
# submission_date        float64
# incident_date           object
# report_date_flag        object
# incident_hour          float64
# cleared_except_id        int64
# cleared_except_date     object
# incident_status          int64
# data_home               object
# ddocname                object
# orig_format            float64
# ff_line_number         float64
# did                    float64
# dtype: object 17
#
# agency_id                int64
# incident_id              int64
# nibrs_month_id           int64
# incident_number          int64
# cargo_theft_flag        object
# submission_date        float64
# incident_date           object
# report_date_flag        object
# incident_hour          float64
# cleared_except_id        int64
# cleared_except_date     object
# incident_status          int64
# data_home               object
# ddocname                object
# orig_format            float64
# ff_line_number         float64
# did                    float64
# dtype: object 17
#
# agency_id                int64
# incident_id              int64
# nibrs_month_id           int64
# incident_number          int64
# cargo_theft_flag        object
# submission_date        float64
# incident_date           object
# report_date_flag        object
# incident_hour          float64
# cleared_except_id        int64
# cleared_except_date     object
# incident_status          int64
# data_home               object
# ddocname                object
# orig_format            float64
# ff_line_number         float64
# did                    float64
# dtype: object 17
#
# agency_id                int64
# incident_id              int64
# nibrs_month_id           int64
# incident_number          int64
# cargo_theft_flag        object
# submission_date         object
# incident_date           object
# report_date_flag        object
# incident_hour          float64
# cleared_except_id        int64
# cleared_except_date     object
# incident_status          int64
# data_home               object
# ddocname                object
# orig_format             object
# ff_line_number         float64
# did                    float64
# dtype: object 17
#
# agency_id                int64
# incident_id              int64
# nibrs_month_id           int64
# incident_number          int64
# cargo_theft_flag        object
# submission_date         object
# incident_date           object
# report_date_flag        object
# incident_hour          float64
# cleared_except_id        int64
# cleared_except_date     object
# incident_status          int64
# data_home               object
# ddocname                object
# orig_format             object
# ff_line_number         float64
# did                      int64
# dtype: object 17
#
# DATA_YEAR                int64
# AGENCY_ID                int64
# INCIDENT_ID              int64
# NIBRS_MONTH_ID           int64
# CARGO_THEFT_FLAG        object
# SUBMISSION_DATE         object
# INCIDENT_DATE           object
# REPORT_DATE_FLAG        object
# INCIDENT_HOUR          float64
# CLEARED_EXCEPT_ID        int64
# CLEARED_EXCEPT_DATE     object
# INCIDENT_STATUS          int64
# DATA_HOME               object
# ORIG_FORMAT             object
# DID                      int64
# dtype: object 15
#
# DATA_YEAR                int64
# AGENCY_ID                int64
# INCIDENT_ID              int64
# NIBRS_MONTH_ID           int64
# CARGO_THEFT_FLAG        object
# SUBMISSION_DATE         object
# INCIDENT_DATE           object
# REPORT_DATE_FLAG        object
# INCIDENT_HOUR          float64
# CLEARED_EXCEPT_ID        int64
# CLEARED_EXCEPT_DATE     object
# INCIDENT_STATUS          int64
# DATA_HOME               object
# ORIG_FORMAT             object
# DID                      int64
# dtype: object 15
#
# DATA_YEAR                int64
# AGENCY_ID                int64
# INCIDENT_ID              int64
# NIBRS_MONTH_ID           int64
# CARGO_THEFT_FLAG        object
# SUBMISSION_DATE         object
# INCIDENT_DATE           object
# REPORT_DATE_FLAG        object
# INCIDENT_HOUR          float64
# CLEARED_EXCEPT_ID        int64
# CLEARED_EXCEPT_DATE     object
# INCIDENT_STATUS          int64
# DATA_HOME               object
# ORIG_FORMAT             object
# DID                      int64
# dtype: object 15

# %% [markdown]
# Looking at the columns, a couple things stand out - some of the files, the column names are in All CAPS which could cause problems when the data is joined/concatenated. \
# \
# The other thing is that those same years where the data is capitalized also have an additional column at the start called "DATA_YEAR". \
# It might be worth ensuring this is replicated across all of the data frames.

# %%
for frame in incident_lst: # Fortunately, we can check whether the DATA YEAR column is not in the frame and if so we can add it AND we can capitalize the column names
    if 'DATA_YEAR' not in frame.columns:
        frame.insert(0, 'DATA_YEAR', value=np.NaN)
        frame.drop(['incident_number', 'ddocname', 'ff_line_number'], axis=1, inplace=True)
    frame.columns = [column.upper() for column in frame.columns]

# %%
for frame in incident_lst:
    print(frame.columns, len(frame.columns))
# Out:
# Index(['DATA_YEAR', 'AGENCY_ID', 'INCIDENT_ID', 'NIBRS_MONTH_ID',
#        'CARGO_THEFT_FLAG', 'SUBMISSION_DATE', 'INCIDENT_DATE',
#        'REPORT_DATE_FLAG', 'INCIDENT_HOUR', 'CLEARED_EXCEPT_ID',
#        'CLEARED_EXCEPT_DATE', 'INCIDENT_STATUS', 'DATA_HOME', 'ORIG_FORMAT',
#        'DID'],
#       dtype='object') 15
# Index(['DATA_YEAR', 'AGENCY_ID', 'INCIDENT_ID', 'NIBRS_MONTH_ID',
#        'CARGO_THEFT_FLAG', 'SUBMISSION_DATE', 'INCIDENT_DATE',
#        'REPORT_DATE_FLAG', 'INCIDENT_HOUR', 'CLEARED_EXCEPT_ID',
#        'CLEARED_EXCEPT_DATE', 'INCIDENT_STATUS', 'DATA_HOME', 'ORIG_FORMAT',
#        'DID'],
#       dtype='object') 15
# Index(['DATA_YEAR', 'AGENCY_ID', 'INCIDENT_ID', 'NIBRS_MONTH_ID',
#        'CARGO_THEFT_FLAG', 'SUBMISSION_DATE', 'INCIDENT_DATE',
#        'REPORT_DATE_FLAG', 'INCIDENT_HOUR', 'CLEARED_EXCEPT_ID',
#        'CLEARED_EXCEPT_DATE', 'INCIDENT_STATUS', 'DATA_HOME', 'ORIG_FORMAT',
#        'DID'],
#       dtype='object') 15
# Index(['DATA_YEAR', 'AGENCY_ID', 'INCIDENT_ID', 'NIBRS_MONTH_ID',
#        'CARGO_THEFT_FLAG', 'SUBMISSION_DATE', 'INCIDENT_DATE',
#        'REPORT_DATE_FLAG', 'INCIDENT_HOUR', 'CLEARED_EXCEPT_ID',
#        'CLEARED_EXCEPT_DATE', 'INCIDENT_STATUS', 'DATA_HOME', 'ORIG_FORMAT',
#        'DID'],
#       dtype='object') 15
# Index(['DATA_YEAR', 'AGENCY_ID', 'INCIDENT_ID', 'NIBRS_MONTH_ID',
#        'CARGO_THEFT_FLAG', 'SUBMISSION_DATE', 'INCIDENT_DATE',
#        'REPORT_DATE_FLAG', 'INCIDENT_HOUR', 'CLEARED_EXCEPT_ID',
#        'CLEARED_EXCEPT_DATE', 'INCIDENT_STATUS', 'DATA_HOME', 'ORIG_FORMAT',
#        'DID'],
#       dtype='object') 15
# Index(['DATA_YEAR', 'AGENCY_ID', 'INCIDENT_ID', 'NIBRS_MONTH_ID',
#        'CARGO_THEFT_FLAG', 'SUBMISSION_DATE', 'INCIDENT_DATE',
#        'REPORT_DATE_FLAG', 'INCIDENT_HOUR', 'CLEARED_EXCEPT_ID',
#        'CLEARED_EXCEPT_DATE', 'INCIDENT_STATUS', 'DATA_HOME', 'ORIG_FORMAT',
#        'DID'],
#       dtype='object') 15
# Index(['DATA_YEAR', 'AGENCY_ID', 'INCIDENT_ID', 'NIBRS_MONTH_ID',
#        'CARGO_THEFT_FLAG', 'SUBMISSION_DATE', 'INCIDENT_DATE',
#        'REPORT_DATE_FLAG', 'INCIDENT_HOUR', 'CLEARED_EXCEPT_ID',
#        'CLEARED_EXCEPT_DATE', 'INCIDENT_STATUS', 'DATA_HOME', 'ORIG_FORMAT',
#        'DID'],
#       dtype='object') 15
# Index(['DATA_YEAR', 'AGENCY_ID', 'INCIDENT_ID', 'NIBRS_MONTH_ID',
#        'CARGO_THEFT_FLAG', 'SUBMISSION_DATE', 'INCIDENT_DATE',
#        'REPORT_DATE_FLAG', 'INCIDENT_HOUR', 'CLEARED_EXCEPT_ID',
#        'CLEARED_EXCEPT_DATE', 'INCIDENT_STATUS', 'DATA_HOME', 'ORIG_FORMAT',
#        'DID'],
#       dtype='object') 15
# Index(['DATA_YEAR', 'AGENCY_ID', 'INCIDENT_ID', 'NIBRS_MONTH_ID',
#        'CARGO_THEFT_FLAG', 'SUBMISSION_DATE', 'INCIDENT_DATE',
#        'REPORT_DATE_FLAG', 'INCIDENT_HOUR', 'CLEARED_EXCEPT_ID',
#        'CLEARED_EXCEPT_DATE', 'INCIDENT_STATUS', 'DATA_HOME', 'ORIG_FORMAT',
#        'DID'],
#       dtype='object') 15
# Index(['DATA_YEAR', 'AGENCY_ID', 'INCIDENT_ID', 'NIBRS_MONTH_ID',
#        'CARGO_THEFT_FLAG', 'SUBMISSION_DATE', 'INCIDENT_DATE',
#        'REPORT_DATE_FLAG', 'INCIDENT_HOUR', 'CLEARED_EXCEPT_ID',
#        'CLEARED_EXCEPT_DATE', 'INCIDENT_STATUS', 'DATA_HOME', 'ORIG_FORMAT',
#        'DID'],
#       dtype='object') 15
# Index(['DATA_YEAR', 'AGENCY_ID', 'INCIDENT_ID', 'NIBRS_MONTH_ID',
#        'CARGO_THEFT_FLAG', 'SUBMISSION_DATE', 'INCIDENT_DATE',
#        'REPORT_DATE_FLAG', 'INCIDENT_HOUR', 'CLEARED_EXCEPT_ID',
#        'CLEARED_EXCEPT_DATE', 'INCIDENT_STATUS', 'DATA_HOME', 'ORIG_FORMAT',
#        'DID'],
#       dtype='object') 15

# %%
inc = pd.concat(incident_lst)

# %%
# We'd like to see what the data looks like across the fully combined frame. We'll use the sample method (and use the random_state parameter to make it consistent) to see across the dataset

# %% [markdown]
# Some additional steps we need to take to clean the data.... the dates (particularly the incident dates) are in very different formats.\
# \
# `DATA YEAR` column data is missing for DataFrames where we added `DATA YEAR`.

# %%
inc['INCIDENT_DATE'] = pd.to_datetime(inc['INCIDENT_DATE']) # convert to datetime type

# %%
print(inc.shape)
assert inc.shape[0] == 5704160, "Incorrect number of rows for 2009-2019"
assert inc.shape[1] == 15, "Incorrect number of columns for 2009-2019"
# Out:
# (5704160, 15)

# %%
inc.sample(15)
# Out:
#         DATA_YEAR  AGENCY_ID  INCIDENT_ID  NIBRS_MONTH_ID CARGO_THEFT_FLAG  \
# 543348        NaN       8383     63778140         5991724                N
# 276320        NaN       9049     54040678         5251750              NaN
# 296745        NaN       8454     80071314         6819769              NaN
# 207063        NaN       9049     69219255         6146362              NaN
# 182749        NaN       8929     59024213         5707997              NaN
# 80925         NaN       8610     86005579         7437423              NaN
# 365163        NaN       9067     51517556         5039186              NaN
# 230476        NaN       9049     81232966         6894501                N
# 487291        NaN       8814     47929997         4843273              NaN
# 200715        NaN       9049     84261657         7333768              NaN
# 80146         NaN       8293     56563404         5250994              NaN
# 357443     2019.0       8549    114167944         8175172                N
# 420145        NaN       8850     73010378         6614358                N
# 364595        NaN       8581     93399399         7463392              NaN
# 438693     2017.0       8930     94506102         7815840                N
#
#             SUBMISSION_DATE INCIDENT_DATE REPORT_DATE_FLAG  INCIDENT_HOUR  \
# 543348                  NaN    2012-10-17              NaN           21.0
# 276320                  NaN    2010-06-02                R            NaN
# 296745                  NaN    2015-04-16              NaN           20.0
# 207063                  NaN    2013-02-02              NaN            6.0
# 182749                  NaN    2011-12-08              NaN            8.0
# 80925   2017-11-06 00:00:00    2016-03-09              NaN           20.0
# 365163                  NaN    2009-11-27              NaN            0.0
# 230476                  NaN    2015-10-31                R            NaN
# 487291                  NaN    2009-02-11                R            NaN
# 200715  2017-11-06 00:00:00    2016-02-04              NaN           18.0
# 80146                   NaN    2010-06-24              NaN           19.0
# 357443            04-SEP-19    2019-05-14              NaN           19.0
# 420145                  NaN    2014-08-01              NaN           23.0
# 364595  2017-11-07 00:00:00    2016-04-09                R           18.0
# 438693            17-AUG-18    2017-12-07              NaN           19.0
#
#         CLEARED_EXCEPT_ID  CLEARED_EXCEPT_DATE  INCIDENT_STATUS DATA_HOME  \
# 543348                  6                  NaN                0         C
# 276320                  6                  NaN                0         C
# 296745                  6                  NaN                0         C
# 207063                  6                  NaN                0         C
# 182749                  6                  NaN                0         C
# 80925                   2  2016-03-11 00:00:00                0         C
# 365163                  6                  NaN                0         C
# 230476                  6                  NaN                0         C
# 487291                  6                  NaN                0         C
# 200715                  6                  NaN                0         C
# 80146                   6                  NaN                0         C
# 357443                  6                  NaN                0         C
# 420145                  6                  NaN                0         C
# 364595                  6                  NaN                0         C
# 438693                  6                  NaN                0         C
#
#        ORIG_FORMAT         DID
# 543348         NaN         NaN
# 276320         NaN         NaN
# 296745         NaN         NaN
# 207063         NaN         NaN
# 182749         NaN         NaN
# 80925            F   7932912.0
# 365163         NaN         NaN
# 230476         NaN         NaN
# 487291         NaN         NaN
# 200715           F   4356973.0
# 80146          NaN         NaN
# 357443           F  51894619.0
# 420145         NaN         NaN
# 364595           F  22663878.0
# 438693           F  14718673.0

# %%
inc.groupby(inc['INCIDENT_DATE'].dt.year)['INCIDENT_ID'].agg('count')
# Out:
# INCIDENT_DATE
# 2009    617838
# 2010    597205
# 2011    564424
# 2012    562587
# 2013    522879
# 2014    492028
# 2015    487547
# 2016    504997
# 2017    477382
# 2018    458209
# 2019    419064
# Name: INCIDENT_ID, dtype: int64

# %%
inc['DATA_YEAR'] = inc['INCIDENT_DATE'].dt.year # source year for DATA YEAR from INCIDENT_DATE w/ datetime accessor
inc = inc[['DATA_YEAR', 'AGENCY_ID', 'INCIDENT_ID','INCIDENT_DATE','INCIDENT_HOUR']]

# %%
inc.to_csv('../01_nibrs_rawdata/Combined_Incidents.csv', index=False)

# %% [markdown]
# <a id='agencies'></a>

# %% [markdown]
# &nbsp;
#
# ## AGENCIES
#
# We'll take a quick inspection of the agencies to see whether their name changed over the course of the 10 years.

# %%
# Let's check what agencies we care to focus on. I'll use Ann Arbor as a search term
test = agencies_lst[0] # 2009's agency list
test[test['agency_name'].str.contains('Ann Arbor') == True]
# Out:
#      agency_id        ori legacy_ori                        agency_name  \
# 542       9030  MI8121800  MI8121800        Ann Arbor Police Department
# 567       9040  MI8190300  MI8190300  University of Michigan: Ann Arbor
#
#                             short_name  agency_type_id       agency_type_name  \
# 542                          Ann Arbor               1                   City
# 567  University of Michigan: Ann Arbor               3  University or College
#
#      tribe_id  campus_id  city_id  city_name  state_id state_abbr  \
# 542       NaN        NaN   4504.0  Ann Arbor        26         MI
# 567       NaN      764.0      NaN        NaN        26         MI
#
#      primary_county_id primary_county  primary_county_fips agency_status  \
# 542               1324      Washtenaw              26161.0             A
# 567               1324      Washtenaw              26161.0             A
#
#      submitting_agency_id submitting_sai  \
# 542                 23374      MIUCR0001
# 567                 23374      MIUCR0001
#
#                                        submitting_name submitting_state_abbr  \
# 542  Michigan State Police Statistical Records Divi...                    MI
# 567  Michigan State Police Statistical Records Divi...                    MI
#
#      start_year  dormant_year  current_year  revised_rape_start  \
# 542        1960           NaN          2016              2013.0
# 567        1991           NaN          2016              2013.0
#
#      current_nibrs_start_year  population population_group_code  \
# 542                    2016.0      118730                     2
# 567                    2016.0           0                     7
#
#                 population_group_desc population_source_flag  \
# 542  Cities from 100,000 thru 249,000                      L
# 567                Cities under 2,500                      L
#
#     suburban_area_flag core_city_flag  months_reported  nibrs_months_reported  \
# 542                  N              Y               12                     12
# 567                  Y              N               12                     12
#
#      past_10_years_reported  covered_by_id covered_by_ori covered_by_name  \
# 542                      10            NaN            NaN             NaN
# 567                      10            NaN            NaN             NaN
#
#      staffing_year  total_officers  total_civilians icpsr_zip  icpsr_lat  \
# 542         2016.0           125.0             26.0     48104  42.252327
# 567         2016.0            59.0             17.0     48502  42.252327
#
#      icpsr_lng DATA_YEAR
# 542 -83.844634      2009
# 567 -83.844634      2009

# %%
# Let's do the same for MSU.
# Using East Lansing is not going to get us MSU, so I'm searching for both the EL police and the university
(test[(test['agency_name'].str.contains('East Lansing') == True) 
    | (test['agency_name'].str.contains('Michigan State University') == True)])
# Out:
#      agency_id        ori legacy_ori                     agency_name  \
# 111       8554  MI3358100  MI3358100       Michigan State University
# 427       8550  MI3336400  MI3336400  East Lansing Police Department
#
#                     short_name  agency_type_id       agency_type_name  \
# 111  Michigan State University               3  University or College
# 427               East Lansing               1                   City
#
#      tribe_id  campus_id  city_id     city_name  state_id state_abbr  \
# 111       NaN      365.0      NaN           NaN        26         MI
# 427       NaN        NaN   4623.0  East Lansing        26         MI
#
#      primary_county_id primary_county  primary_county_fips agency_status  \
# 111               1276         Ingham              26065.0             A
# 427               1276         Ingham              26065.0             A
#
#      submitting_agency_id submitting_sai  \
# 111                 23374      MIUCR0001
# 427                 23374      MIUCR0001
#
#                                        submitting_name submitting_state_abbr  \
# 111  Michigan State Police Statistical Records Divi...                    MI
# 427  Michigan State Police Statistical Records Divi...                    MI
#
#      start_year  dormant_year  current_year  revised_rape_start  \
# 111        1960           NaN          2016              2013.0
# 427        1960           NaN          2016              2013.0
#
#      current_nibrs_start_year  population population_group_code  \
# 111                    2016.0           0                     7
# 427                    2016.0       48668                     4
#
#               population_group_desc population_source_flag suburban_area_flag  \
# 111              Cities under 2,500                      L                  Y
# 427  Cities from 25,000 thru 49,999                      L                  N
#
#     core_city_flag  months_reported  nibrs_months_reported  \
# 111              N               12                     12
# 427              Y               12                     12
#
#      past_10_years_reported  covered_by_id covered_by_ori covered_by_name  \
# 111                      10            NaN            NaN             NaN
# 427                      10            NaN            NaN             NaN
#
#      staffing_year  total_officers  total_civilians icpsr_zip  icpsr_lat  \
# 111         2016.0            85.0             28.0     48824  42.603534
# 427         2016.0            54.0             13.0     48823  42.603534
#
#      icpsr_lng DATA_YEAR
# 111 -84.373811      2009
# 427 -84.373811      2009

# %% [markdown]
# &nbsp;
#
# We have the agency ids that we care about, now let's see how names / info change for each agency as we move across years

# %%
first_agency = agencies_lst[1] # 2010 dataset
# first_agency[first_agency['agency_name'].str.contains("Michigan State")==True]

first_agency[first_agency['agency_id'].isin([9030, 9040]) == True]
# first_agency[first_agency['agency_id']== 8286]
# Out:
#      agency_id        ori legacy_ori                        agency_name  \
# 542       9030  MI8121800  MI8121800        Ann Arbor Police Department
# 567       9040  MI8190300  MI8190300  University of Michigan: Ann Arbor
#
#                             short_name  agency_type_id       agency_type_name  \
# 542                          Ann Arbor               1                   City
# 567  University of Michigan: Ann Arbor               3  University or College
#
#      tribe_id  campus_id  city_id  city_name  state_id state_abbr  \
# 542       NaN        NaN   4504.0  Ann Arbor        26         MI
# 567       NaN      764.0      NaN        NaN        26         MI
#
#      primary_county_id primary_county  primary_county_fips agency_status  \
# 542               1324      Washtenaw              26161.0             A
# 567               1324      Washtenaw              26161.0             A
#
#      submitting_agency_id submitting_sai  \
# 542                 23374      MIUCR0001
# 567                 23374      MIUCR0001
#
#                                        submitting_name submitting_state_abbr  \
# 542  Michigan State Police Statistical Records Divi...                    MI
# 567  Michigan State Police Statistical Records Divi...                    MI
#
#      start_year  dormant_year  current_year  revised_rape_start  \
# 542        1960           NaN          2016              2013.0
# 567        1991           NaN          2016              2013.0
#
#      current_nibrs_start_year  population population_group_code  \
# 542                    2016.0      118730                     2
# 567                    2016.0           0                     7
#
#                 population_group_desc population_source_flag  \
# 542  Cities from 100,000 thru 249,000                      L
# 567                Cities under 2,500                      L
#
#     suburban_area_flag core_city_flag  months_reported  nibrs_months_reported  \
# 542                  N              Y               12                     12
# 567                  Y              N               12                     12
#
#      past_10_years_reported  covered_by_id covered_by_ori covered_by_name  \
# 542                      10            NaN            NaN             NaN
# 567                      10            NaN            NaN             NaN
#
#      staffing_year  total_officers  total_civilians icpsr_zip  icpsr_lat  \
# 542         2016.0           125.0             26.0     48104  42.252327
# 567         2016.0            59.0             17.0     48502  42.252327
#
#      icpsr_lng DATA_YEAR
# 542 -83.844634      2010
# 567 -83.844634      2010

# %%
second_agency = agencies_lst[-1] # [-1] refers to 2019 agencies list
# second_agency.head()

second_agency[second_agency['AGENCY_ID'].isin([9030, 9040]) == True]
# Out:
#      YEARLY_AGENCY_ID  AGENCY_ID DATA_YEAR        ORI LEGACY_ORI  \
# 553          90302019       9030      2019  MI8121800  MI8121800
# 560          90402019       9040      2019  MI8190300  MI8190300
#
#     COVERED_BY_LEGACY_ORI DIRECT_CONTRIBUTOR_FLAG DORMANT_FLAG  DORMANT_YEAR  \
# 553                   NaN                       N            N           NaN
# 560                   NaN                       N            N           NaN
#
#     REPORTING_TYPE        UCR_AGENCY_NAME  \
# 553              I              ANN ARBOR
# 560              I  UNIV OF MI: ANN ARBOR
#
#                                  NCIC_AGENCY_NAME          PUB_AGENCY_NAME  \
# 553                                  ANN ARBOR PD                Ann Arbor
# 560  UNIV OF MICH DEPT OF PUBLIC SAFETY ANN ARBOR  University of Michigan:
#
#     PUB_AGENCY_UNIT AGENCY_STATUS  STATE_ID STATE_NAME STATE_ABBR  \
# 553             NaN             A        26   Michigan         MI
# 560       Ann Arbor             A        26   Michigan         MI
#
#     STATE_POSTAL_ABBR  DIVISION_CODE       DIVISION_NAME  REGION_CODE  \
# 553                MI              3  East North Central            2
# 560                MI              3  East North Central            2
#
#     REGION_NAME REGION_DESC       AGENCY_TYPE_NAME  POPULATION  \
# 553     Midwest   Region II                   City      122893
# 560     Midwest   Region II  University or College           0
#
#      SUBMITTING_AGENCY_ID        SAI  \
# 553                 23374  MIUCR0001
# 560                 23374  MIUCR0001
#
#                                 SUBMITTING_AGENCY_NAME SUBURBAN_AREA_FLAG  \
# 553  Michigan State Police Criminal Justice Informa...                  N
# 560  Michigan State Police Criminal Justice Informa...                  Y
#
#      POPULATION_GROUP_ID POPULATION_GROUP_CODE  \
# 553                    6                     2
# 560                   11                     7
#
#                 POPULATION_GROUP_DESC  PARENT_POP_GROUP_CODE  \
# 553  Cities from 100,000 thru 249,999                      2
# 560                Cities under 2,500                      7
#
#                 PARENT_POP_GROUP_DESC MIP_FLAG  POP_SORT_ORDER  \
# 553  Cities from 100,000 thru 249,999        Y               1
# 560                Cities under 2,500        N               2
#
#     SUMMARY_RAPE_DEF PE_REPORTED_FLAG  MALE_OFFICER  MALE_CIVILIAN  \
# 553                R                Y          96.0            9.0
# 560                R                Y          49.0            8.0
#
#      PED.MALE_OFFICER+PED.MALE_CIVILIAN  FEMALE_OFFICER  FEMALE_CIVILIAN  \
# 553                               105.0            28.0             20.0
# 560                                57.0            12.0              8.0
#
#      PED.FEMALE_CIVILIAN+PED.FEMALE_OFFICER  0  0.1 NIBRS_CERT_DATE  \
# 553                                    48.0  0    0       01-OCT-94
# 560                                    20.0  0    0       01-OCT-94
#
#     NIBRS_START_DATE NIBRS_LEOKA_START_DATE NIBRS_CT_START_DATE  \
# 553        01-JAN-03              01-JUN-09           01-JUL-12
# 560        01-JAN-95              01-JUL-09           01-JUL-12
#
#     NIBRS_MULTI_BIAS_START_DATE NIBRS_OFF_ETH_START_DATE COVERED_FLAG  \
# 553                   01-JAN-17                01-JAN-17            N
# 560                   01-JAN-17                01-JAN-17            N
#
#     COUNTY_NAME       MSA_NAME PUBLISHABLE_FLAG PARTICIPATED  \
# 553   WASHTENAW  Ann Arbor, MI                Y            Y
# 560   WASHTENAW  Ann Arbor, MI                Y            Y
#
#     NIBRS_PARTICIPATED
# 553                  Y
# 560                  Y

# %%
second_agency[second_agency['AGENCY_ID'].isin([8554, 8550]) == True] \
[['AGENCY_ID','UCR_AGENCY_NAME','NCIC_AGENCY_NAME', 'PUB_AGENCY_UNIT','AGENCY_TYPE_NAME','DATA_YEAR']]
# Out:
#      AGENCY_ID           UCR_AGENCY_NAME               NCIC_AGENCY_NAME  \
# 207       8550              EAST LANSING                EAST LANSING PD
# 211       8554  MICHIGAN STATE UNIVERSIT  MI STATE UNIV PD EAST LANSING
#
#     PUB_AGENCY_UNIT       AGENCY_TYPE_NAME DATA_YEAR
# 207             NaN                   City      2019
# 211             NaN  University or College      2019

# %%
first_agency[first_agency['agency_id'].isin([8554, 8550]) == True]
# Out:
#      agency_id        ori legacy_ori                     agency_name  \
# 111       8554  MI3358100  MI3358100       Michigan State University
# 427       8550  MI3336400  MI3336400  East Lansing Police Department
#
#                     short_name  agency_type_id       agency_type_name  \
# 111  Michigan State University               3  University or College
# 427               East Lansing               1                   City
#
#      tribe_id  campus_id  city_id     city_name  state_id state_abbr  \
# 111       NaN      365.0      NaN           NaN        26         MI
# 427       NaN        NaN   4623.0  East Lansing        26         MI
#
#      primary_county_id primary_county  primary_county_fips agency_status  \
# 111               1276         Ingham              26065.0             A
# 427               1276         Ingham              26065.0             A
#
#      submitting_agency_id submitting_sai  \
# 111                 23374      MIUCR0001
# 427                 23374      MIUCR0001
#
#                                        submitting_name submitting_state_abbr  \
# 111  Michigan State Police Statistical Records Divi...                    MI
# 427  Michigan State Police Statistical Records Divi...                    MI
#
#      start_year  dormant_year  current_year  revised_rape_start  \
# 111        1960           NaN          2016              2013.0
# 427        1960           NaN          2016              2013.0
#
#      current_nibrs_start_year  population population_group_code  \
# 111                    2016.0           0                     7
# 427                    2016.0       48668                     4
#
#               population_group_desc population_source_flag suburban_area_flag  \
# 111              Cities under 2,500                      L                  Y
# 427  Cities from 25,000 thru 49,999                      L                  N
#
#     core_city_flag  months_reported  nibrs_months_reported  \
# 111              N               12                     12
# 427              Y               12                     12
#
#      past_10_years_reported  covered_by_id covered_by_ori covered_by_name  \
# 111                      10            NaN            NaN             NaN
# 427                      10            NaN            NaN             NaN
#
#      staffing_year  total_officers  total_civilians icpsr_zip  icpsr_lat  \
# 111         2016.0            85.0             28.0     48824  42.603534
# 427         2016.0            54.0             13.0     48823  42.603534
#
#      icpsr_lng DATA_YEAR
# 111 -84.373811      2010
# 427 -84.373811      2010

# %% [markdown]
# Comparing the two different dataframes (2010 vs. 2019) there are quite a few differences. \
# \
# The biggest challenge is that the naming of the agency (which provides attribution for the the incident / offense) changes. \
# \
# Where 2010 simply had an agency name, 2019 is showing that the name is split between different reporting systems / agencies, so it's really just a matter of choosing a column that is closest to the `agency_name` column found in the older datasets. \
# \
# Fortunately, it appears that the core `agency_id` values are still intact among all years:
# -  **9040 is University of Michigan Police**
# -  **8554 is Michigan State University Police**
#
# ---
# Of less concern but worthy to note, both types of datasets contain a field with county, but the columns are labeled a bit differently (`primary county` vs. `COUNTY NAME`).\
# \
# That might also be helpful to include if we want to investigate a little more broadly geographically. \
# \
# Also, `DATA_YEAR` is not found in the old dataset under that name, but we can use the `current_year` column to get that information.\
# \
# Now that we have a sense of the differences, we can reduce each dataframe down to only the fields we care about, and in the process, ensure that the columns are consistently named, so we concatenate them together successfully.

# %%
clean_agencies_lst = []
for frame in agencies_lst: # for each year's cde_agencies.csv or agencies.csv, reduce to common columns and give them consistent naming
    if len(frame.columns) < 59:
        frame = frame[['agency_id','agency_name','primary_county', 'agency_type_name', 'DATA_YEAR']]
    else:
        frame = frame[['AGENCY_ID','UCR_AGENCY_NAME','PUB_AGENCY_UNIT','AGENCY_TYPE_NAME','DATA_YEAR']]
        
    frame.columns = ['AGENCY_ID','AGENCY_NAME','COUNTY','TYPE','YEAR']
    clean_agencies_lst.append(frame)

# %% [markdown]
# &nbsp;

# %%
# Concatenate across the years and see what the output is for one of the agencies we care about
agen = pd.concat(clean_agencies_lst)
agen[agen['AGENCY_ID'] == 9040]
# Out:
#      AGENCY_ID                        AGENCY_NAME     COUNTY  \
# 567       9040  University of Michigan: Ann Arbor  Washtenaw
# 567       9040  University of Michigan: Ann Arbor  Washtenaw
# 571       9040  University of Michigan: Ann Arbor  Washtenaw
# 571       9040  University of Michigan: Ann Arbor  Washtenaw
# 571       9040  University of Michigan: Ann Arbor  Washtenaw
# 580       9040  University of Michigan: Ann Arbor  Washtenaw
# 705       9040  University of Michigan: Ann Arbor  Washtenaw
# 527       9040  University of Michigan: Ann Arbor  Washtenaw
# 553       9040              UNIV OF MI: ANN ARBOR  Ann Arbor
# 556       9040              UNIV OF MI: ANN ARBOR  Ann Arbor
# 560       9040              UNIV OF MI: ANN ARBOR  Ann Arbor
#
#                       TYPE  YEAR
# 567  University or College  2009
# 567  University or College  2010
# 571  University or College  2011
# 571  University or College  2012
# 571  University or College  2013
# 580  University or College  2014
# 705  University or College  2015
# 527  University or College  2016
# 553  University or College  2017
# 556  University or College  2018
# 560  University or College  2019

# %%
# and again for MSU
agen[agen['AGENCY_ID'] == 8554]
# Out:
#      AGENCY_ID                AGENCY_NAME  COUNTY                   TYPE  YEAR
# 111       8554  Michigan State University  Ingham  University or College  2009
# 111       8554  Michigan State University  Ingham  University or College  2010
# 112       8554  Michigan State University  Ingham  University or College  2011
# 112       8554  Michigan State University  Ingham  University or College  2012
# 112       8554  Michigan State University  Ingham  University or College  2013
# 115       8554  Michigan State University  Ingham  University or College  2014
# 39        8554  Michigan State University  Ingham  University or College  2015
# 30        8554  Michigan State University  Ingham  University or College  2016
# 208       8554   MICHIGAN STATE UNIVERSIT     NaN  University or College  2017
# 205       8554   MICHIGAN STATE UNIVERSIT     NaN  University or College  2018
# 211       8554   MICHIGAN STATE UNIVERSIT     NaN  University or College  2019

# %% [markdown]
# Since there's a lot of duplication in this data (same agencies appear for multiple years), we want to condense it down to only the unique agencies and pull in the other details like county, etc.\
# \
# We have to account for the fact that there might be agency ids that existed in earlier years that don't have in the latter.  We'll groupby() by the agency id and get the highest year (most recent) that we have record of them.  We'll convert this to a dataframe and give the same named columns as what the larger dataframe has in preparation for a merge.

# %%
maxagens = agen.groupby('AGENCY_ID')['YEAR'].agg('max')
unique_agens = maxagens.to_frame().reset_index()
unique_agens.columns = ['AGENCY_ID','YEAR']

# %% [markdown]
# Next, we'll merge the datasets on the agency_id and year (common to both datasets) and get the details from duplicated table.  We'll save this off as a .csv file.

# %%
combined = unique_agens.merge(agen, how='left', on=['AGENCY_ID', 'YEAR'])
combined.to_csv('../01_nibrs_rawdata/agencies.csv',index=False)

# %%
combined
# Out:
#      AGENCY_ID  YEAR                     AGENCY_NAME         COUNTY  \
# 0         8286  2019               SP: ALCONA COUNTY  Alcona County
# 1         8287  2019                          ALCONA            NaN
# 2         8288  2015   Harrisville Police Department         Alcona
# 3         8289  2015       Lincoln Police Department         Alcona
# 4         8290  2019                SP: ALGER COUNTY   Alger County
# ..         ...   ...                             ...            ...
# 838      26021  2019           STATE POLICE, DETROIT            NaN
# 839      26624  2019     METRO POL AUTH GENESEE CNTY            NaN
# 840      28034  2019  DEPT NAT RESOURCES LAW ENF DIV            NaN
# 841      28154  2019     WASHTENAW COMMUNITY COLLEGE            NaN
# 842      30474  2019            GRAND BEACH/MICHIANA            NaN
#
#                       TYPE
# 0             State Police
# 1                   County
# 2                     City
# 3                     City
# 4             State Police
# ..                     ...
# 838           State Police
# 839                   City
# 840     Other State Agency
# 841  University or College
# 842                   City
#
# [843 rows x 5 columns]

# %% [markdown]
# <a id='offense_type'></a>

# %% [markdown]
# &nbsp;
#
# ## OFFENSE TYPE

# %%
for frame in offense_type_lst:
    print(frame.columns, len(frame.columns))
# Out:
# Index(['offense_type_id', 'offense_code', 'offense_name', 'crime_against',
#        'ct_flag', 'hc_flag', 'hc_code', 'offense_category_name', 'DATA_YEAR'],
#       dtype='object') 9
# Index(['offense_type_id', 'offense_code', 'offense_name', 'crime_against',
#        'ct_flag', 'hc_flag', 'hc_code', 'offense_category_name', 'DATA_YEAR'],
#       dtype='object') 9
# Index(['offense_type_id', 'offense_code', 'offense_name', 'crime_against',
#        'ct_flag', 'hc_flag', 'hc_code', 'offense_category_name', 'DATA_YEAR'],
#       dtype='object') 9
# Index(['offense_type_id', 'offense_code', 'offense_name', 'crime_against',
#        'ct_flag', 'hc_flag', 'hc_code', 'offense_category_name', 'DATA_YEAR'],
#       dtype='object') 9
# Index(['offense_type_id', 'offense_code', 'offense_name', 'crime_against',
#        'ct_flag', 'hc_flag', 'hc_code', 'offense_category_name', 'DATA_YEAR'],
#       dtype='object') 9
# Index(['offense_type_id', 'offense_code', 'offense_name', 'crime_against',
#        'ct_flag', 'hc_flag', 'hc_code', 'offense_category_name', 'DATA_YEAR'],
#       dtype='object') 9
# Index(['offense_type_id', 'offense_code', 'offense_name', 'crime_against',
#        'ct_flag', 'hc_flag', 'hc_code', 'offense_category_name', 'DATA_YEAR'],
#       dtype='object') 9
# Index(['offense_type_id', 'offense_code', 'offense_name', 'crime_against',
#        'ct_flag', 'hc_flag', 'hc_code', 'offense_category_name', 'DATA_YEAR'],
#       dtype='object') 9
# Index(['OFFENSE_TYPE_ID', 'OFFENSE_CODE', 'OFFENSE_NAME', 'CRIME_AGAINST',
#        'CT_FLAG', 'HC_FLAG', 'HC_CODE', 'OFFENSE_CATEGORY_NAME',
#        'OFFENSE_GROUP', 'DATA_YEAR'],
#       dtype='object') 10
# Index(['OFFENSE_TYPE_ID', 'OFFENSE_CODE', 'OFFENSE_NAME', 'CRIME_AGAINST',
#        'CT_FLAG', 'HC_FLAG', 'HC_CODE', 'OFFENSE_CATEGORY_NAME',
#        'OFFENSE_GROUP', 'DATA_YEAR'],
#       dtype='object') 10
# Index(['OFFENSE_TYPE_ID', 'OFFENSE_CODE', 'OFFENSE_NAME', 'CRIME_AGAINST',
#        'CT_FLAG', 'HC_FLAG', 'HC_CODE', 'OFFENSE_CATEGORY_NAME',
#        'OFFENSE_GROUP', 'DATA_YEAR'],
#       dtype='object') 10

# %% [markdown]
# Looks like there is some variation here - capitalization of column names in later files and the addition of column `OFFENSE_GROUP`.\
# \
# To keep it simple, we'll only extract the ID and Name

# %%
offense_type_lst[0].head()
# Out:
#    offense_type_id offense_code                             offense_name  \
# 0               58          23*                            Not Specified
# 1                1          09C                     Justifiable Homicide
# 2                2          26A  False Pretenses/Swindle/Confidence Game
# 3                3          36B                           Statutory Rape
# 4                4          11C            Sexual Assault With An Object
#
#   crime_against ct_flag hc_flag  hc_code   offense_category_name DATA_YEAR
# 0      Property       N       Y      6.0  Larceny/Theft Offenses      2009
# 1   Not a Crime       N       N      NaN       Homicide Offenses      2009
# 2      Property       Y       Y      NaN          Fraud Offenses      2009
# 3        Person       N       Y      NaN            Sex Offenses      2009
# 4        Person       N       Y      2.0            Sex Offenses      2009

# %%
offense_type_lst[-1].sample(10)
# Out:
#     OFFENSE_TYPE_ID OFFENSE_CODE                          OFFENSE_NAME  \
# 14               85          61B              Federal Tobacco Offenses
# 3                74          30D            Re-entry after Deportation
# 10               81          526                  Explosives Violation
# 82               66          90L           Federal Resource Violations
# 56               32          09A  Murder and Nonnegligent Manslaughter
# 31                6          90F           Family Offenses, Nonviolent
# 45               21          240                   Motor Vehicle Theft
# 37               13          23A                        Pocket-picking
# 15               86          620                  Wildlife Trafficking
# 25               58          23*                         Not Specified
#
#    CRIME_AGAINST CT_FLAG HC_FLAG  HC_CODE        OFFENSE_CATEGORY_NAME  \
# 14       Society       N       N      NaN               Other Offenses
# 3        Society       N       N      NaN               Other Offenses
# 10       Society       N       N      NaN               Other Offenses
# 82       Society       N       N      NaN               Other Offenses
# 56        Person       N       Y      1.0            Homicide Offenses
# 31        Person       N       N      NaN  Family Offenses, Nonviolent
# 45      Property       Y       Y      7.0          Motor Vehicle Theft
# 37      Property       N       N      NaN       Larceny/Theft Offenses
# 15       Society       N       N      NaN               Other Offenses
# 25      Property       N       Y      6.0       Larceny/Theft Offenses
#
#    OFFENSE_GROUP DATA_YEAR
# 14             A      2019
# 3              A      2019
# 10             A      2019
# 82             B      2019
# 56             A      2019
# 31             B      2019
# 45             A      2019
# 37             A      2019
# 15             A      2019
# 25             A      2019

# %%
clean_off_type_lst = []
for frame in offense_type_lst:
    if len(frame.columns) == 9:
        temp = frame[['offense_type_id','offense_name', 'crime_against','offense_category_name','DATA_YEAR']]
    else:
        temp = frame[['OFFENSE_TYPE_ID','OFFENSE_NAME','CRIME_AGAINST','OFFENSE_CATEGORY_NAME','DATA_YEAR']]
        
    temp.columns = ['OFFENSE_TYPE_ID','NAME','AGAINST','CATEGORY','YEAR']
    clean_off_type_lst.append(temp)

# %%
off_type = pd.concat(clean_off_type_lst)
print(off_type.shape)
off_type.sample(10)
# Out:
# (748, 5)
#     OFFENSE_TYPE_ID                          NAME   AGAINST  \
# 44               44                  Intimidation    Person
# 34               34     Trespass of Real Property   Society
# 17               17                    Wire Fraud  Property
# 31               31              Betting/Wagering   Society
# 60               37                  Embezzlement  Property
# 28                3                Statutory Rape    Person
# 16               16      Drug/Narcotic Violations   Society
# 63               62                Animal Cruelty   Society
# 33                8  Pornography/Obscene Material   Society
# 48               48            All Other Offenses   Society
#
#                         CATEGORY  YEAR
# 44              Assault Offenses  2015
# 34                           NaN  2014
# 17                Fraud Offenses  2014
# 31             Gambling Offenses  2013
# 60                  Embezzlement  2018
# 28    Sex Offenses, Non-forcible  2019
# 16        Drug/Narcotic Offenses  2015
# 63                Animal Cruelty  2015
# 33  Pornography/Obscene Material  2019
# 48                           NaN  2009

# %%
len(off_type.OFFENSE_TYPE_ID.unique()) # quick check of the number of unique offense types.
# Out:
# 86

# %%
off_type_max = off_type.groupby('OFFENSE_TYPE_ID')['YEAR'].max().to_frame()

# %%
off_types_full = off_type_max.merge(off_type,how='left',on=['OFFENSE_TYPE_ID','YEAR'])

# %%
off_types_full.to_csv('../01_nibrs_rawdata/NIBRS_OFFENSE_TYPE.csv',index=False)

# %% [markdown]
# <a id='offenses'></a>

# %% [markdown]
# &nbsp;
#
# ## OFFENSES

# %%
for frame in offenses_lst:
    print(frame.columns, len(frame.columns))
# Out:
# Index(['DATA_YEAR', 'offense_id', 'incident_id', 'offense_type_id',
#        'attempt_complete_flag', 'location_id', 'num_premises_entered',
#        'method_entry_code', 'ff_line_number'],
#       dtype='object') 9
# Index(['DATA_YEAR', 'offense_id', 'incident_id', 'offense_type_id',
#        'attempt_complete_flag', 'location_id', 'num_premises_entered',
#        'method_entry_code', 'ff_line_number'],
#       dtype='object') 9
# Index(['DATA_YEAR', 'offense_id', 'incident_id', 'offense_type_id',
#        'attempt_complete_flag', 'location_id', 'num_premises_entered',
#        'method_entry_code', 'ff_line_number'],
#       dtype='object') 9
# Index(['DATA_YEAR', 'offense_id', 'incident_id', 'offense_type_id',
#        'attempt_complete_flag', 'location_id', 'num_premises_entered',
#        'method_entry_code', 'ff_line_number'],
#       dtype='object') 9
# Index(['DATA_YEAR', 'offense_id', 'incident_id', 'offense_type_id',
#        'attempt_complete_flag', 'location_id', 'num_premises_entered',
#        'method_entry_code', 'ff_line_number'],
#       dtype='object') 9
# Index(['DATA_YEAR', 'offense_id', 'incident_id', 'offense_type_id',
#        'attempt_complete_flag', 'location_id', 'num_premises_entered',
#        'method_entry_code', 'ff_line_number'],
#       dtype='object') 9
# Index(['DATA_YEAR', 'offense_id', 'incident_id', 'offense_type_id',
#        'attempt_complete_flag', 'location_id', 'num_premises_entered',
#        'method_entry_code', 'ff_line_number'],
#       dtype='object') 9
# Index(['DATA_YEAR', 'offense_id', 'incident_id', 'offense_type_id',
#        'attempt_complete_flag', 'location_id', 'num_premises_entered',
#        'method_entry_code', 'ff_line_number'],
#       dtype='object') 9
# Index(['DATA_YEAR', 'OFFENSE_ID', 'INCIDENT_ID', 'OFFENSE_TYPE_ID',
#        'ATTEMPT_COMPLETE_FLAG', 'LOCATION_ID', 'NUM_PREMISES_ENTERED',
#        'METHOD_ENTRY_CODE'],
#       dtype='object') 8
# Index(['DATA_YEAR', 'OFFENSE_ID', 'INCIDENT_ID', 'OFFENSE_TYPE_ID',
#        'ATTEMPT_COMPLETE_FLAG', 'LOCATION_ID', 'NUM_PREMISES_ENTERED',
#        'METHOD_ENTRY_CODE'],
#       dtype='object') 8
# Index(['DATA_YEAR', 'OFFENSE_ID', 'INCIDENT_ID', 'OFFENSE_TYPE_ID',
#        'ATTEMPT_COMPLETE_FLAG', 'LOCATION_ID', 'NUM_PREMISES_ENTERED',
#        'METHOD_ENTRY_CODE'],
#       dtype='object') 8

# %% [markdown]
# Looks like everything is consistent sans some capitalization...this is no problem.  We only need the first few columns so we'll use indexing to extract those and put them into a list of clean frames

# %%
clean_offense_lst = []
for frame in offenses_lst:
    frame = frame.iloc[:,:4]
    frame.columns = ['YEAR','OFFENSE_ID','INCIDENT_ID','OFFENSE_TYPE_ID']
    clean_offense_lst.append(frame)

# %%
offenses = pd.concat(clean_offense_lst)
offenses.sample(10)
# Out:
#         YEAR  OFFENSE_ID  INCIDENT_ID  OFFENSE_TYPE_ID
# 220460  2012    68888033     64880995               14
# 253565  2018   126737658    102900242               35
# 272223  2015    88309380     81280905               44
# 252230  2017   110643317     88832849               63
# 184130  2018   124647281    101075614               41
# 477363  2013    78379480     70541348               51
# 454459  2010    62232801     56240903               23
# 328919  2013    78298048     70494504               45
# 105727  2012    69789733     62923395               45
# 120452  2010    57378483     55774363                2

# %%
offenses.to_csv('../01_nibrs_rawdata/NIBRS_OFFENSE.csv',index=False)

# %%
offenses.shape
assert offenses.shape[0] == 6002034, "Incorrect number of offenses for 2009-2019"

# %%
inc.shape
assert inc.shape[0] == 5704160, "Incorrect number of incidents for 2009-2019"
