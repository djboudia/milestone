# %%
import numpy as np
import pandas as pd
import os
import glob

pd.set_option('display.max_rows', 500)

# %% [markdown]
# # Sport - NIBRS Join

# %% [markdown]
# [Football poll data](#poll)\
# [Football / basketball data alignment](#alignment)\
# [Spark SQL join](#join)\
# [Checking full DataFrame](#check)

# %% [markdown]
# <a id='poll'></a>

# %% [markdown]
# &nbsp;
#
# ## Football poll data

# %% [markdown]
# [College Football Data Glossary](https://collegefootballdata.com/glossary)

# %%
# create DataFrame 'df' from cfbd .json files, sourced from their /games API endpoint - one .json for each year
df = pd.concat(map(lambda file: pd.read_json(file), 
                   glob.glob(os.path.join('', r'../02_sport_rawdata/cfbd_games_json/' + '*.json'))))
df.reset_index(inplace=True, drop=True)

# create DataFrame 'df_poll' from cfbd .json files, sourced from their /rankings API endpoint - one .json for each year
df_poll = pd.concat(map(lambda file: pd.read_json(file, orient='records'), 
                        glob.glob(os.path.join('', r'../02_sport_rawdata/cfbd_poll_json/' + '*.json'))))
df_poll.reset_index(inplace=True, drop=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8966 entries, 0 to 8965
# Data columns (total 30 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  8966 non-null   int64
#  1   season              8966 non-null   int64
#  2   week                8966 non-null   int64
#  3   season_type         8966 non-null   object
#  4   start_date          8966 non-null   object
#  5   start_time_tbd      0 non-null      float64
#  6   neutral_site        8966 non-null   bool
#  7   conference_game     8966 non-null   bool
#  8   attendance          8963 non-null   float64
#  9   venue_id            8821 non-null   float64
#  10  venue               8821 non-null   object
#  11  home_id             8966 non-null   int64
#  12  home_team           8966 non-null   object
#  13  home_conference     8955 non-null   object
#  14  home_points         8966 non-null   int64
#  15  home_line_scores    8966 non-null   object
#  16  home_post_win_prob  8125 non-null   float64
#  17  home_pregame_elo    7856 non-null   float64
#  18  home_postgame_elo   7856 non-null   float64
#  19  away_id             8966 non-null   int64
#  20  away_team           8966 non-null   object
#  21  away_conference     7813 non-null   object
#  22  away_points         8966 non-null   int64
#  23  away_line_scores    8966 non-null   object
#  24  away_post_win_prob  8125 non-null   float64
#  25  away_pregame_elo    7856 non-null   float64
#  26  away_postgame_elo   7856 non-null   float64
#  27  excitement_index    7346 non-null   float64
#  28  highlights          2705 non-null   object
#  29  notes               1 non-null      object
# dtypes: bool(2), float64(10), int64(7), object(11)
# memory usage: 1.9+ MB

# %%
df_poll.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      168 non-null    int64
#  1   seasonType  168 non-null    object
#  2   week        168 non-null    int64
#  3   polls       168 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 5.4+ KB

# %%
df_lst = []

def GetRankings(poll_data):
    ''' 
    This function takes a row of data and determines from which poll to extract rankings.
    There are 5 polls from which to select for a team's ranking on any given week.
    Note: This is not scaleable for large data due to looping of rows.
    '''
    
    tmp_df = pd.DataFrame(poll_data['polls'])

    search_term = ""
    if poll_data['season'] > 2013:
        if poll_data['week'] < 10: 
            search_term = 'AP Top 25'
        else:
            search_term = 'Playoff Committee'
        
    elif poll_data['season'] == 2013:
        if poll_data['week'] < 9:
            search_term = 'AP Top 25'
        else:
            search_term = 'BCS'
    else:
        if poll_data['week'] < 8:
            search_term = 'AP Top 25'
        else:
            search_term = 'BCS'
    
    if search_term == "":
        search_term = 'AP Top 25 i'
    rank_type = tmp_df[tmp_df['poll'].str.contains(search_term) == True]
    
    if rank_type.shape[0] == 0:
        search_term = 'AP Top 25'
        rank_type = tmp_df[tmp_df['poll'].str.contains('AP') == True]
    try:
        rankings = pd.json_normalize(rank_type.iloc[0]['ranks']).explode(['rank', 'school', 'conference'])
        # temp_ap = pd.json_normalize(r['polls']['poll']['ranks']).explode(['rank','school','conference'])
    except Exception:
        print(poll_data['season'], poll_data['week'], search_term)
        quit()
    
    rankings['season'] = poll_data['season']
    rankings['season_type'] = poll_data['seasonType']
    rankings['week'] = poll_data['week']
    rankings['poll'] = search_term
    
    df_lst.append(rankings)


# We don't want to return anything when we loop through the rows 
# as there will be a list of DataFrames stored we'll use in subsequent cells.
_ = df_poll.apply(lambda r: GetRankings(r),axis=1)

# %%
# Create the dataframe from the list of frames and validate the different polls that we're using and use some basic manipulation
cmb_ranks = pd.concat(df_lst)
cmb_ranks['school'] = cmb_ranks['school'].str.lower()

# Duplicate column for merging for opponent rank values later
cmb_ranks['opponent'] = cmb_ranks['school']
cmb_ranks
# Out:
#     rank          school         conference  firstPlaceVotes  points  season  \
# 0     25       wisconsin            Big Ten                0       0    2009
# 1     10            iowa            Big Ten                0       0    2009
# 2      8      ohio state            Big Ten                0       0    2009
# 3     24             usc             Pac-10                0       0    2009
# 4     21        stanford             Pac-10                0       0    2009
# ..   ...             ...                ...              ...     ...     ...
# 20    21      cincinnati  American Athletic                0       0    2019
# 21    22             usc             Pac-12                0       0    2019
# 22    23            navy  American Athletic                0       0    2019
# 23    24        virginia                ACC                0       0    2019
# 24    25  oklahoma state             Big 12                0       0    2019
#
#    season_type  week               poll        opponent
# 0      regular    15                BCS       wisconsin
# 1      regular    15                BCS            iowa
# 2      regular    15                BCS      ohio state
# 3      regular    15                BCS             usc
# 4      regular    15                BCS        stanford
# ..         ...   ...                ...             ...
# 20     regular    16  Playoff Committee      cincinnati
# 21     regular    16  Playoff Committee             usc
# 22     regular    16  Playoff Committee            navy
# 23     regular    16  Playoff Committee        virginia
# 24     regular    16  Playoff Committee  oklahoma state
#
# [4202 rows x 10 columns]

# %% [markdown]
# <a id='alignment'></a>

# %% [markdown]
# &nbsp;
#
# ## Football / basketball data alignment

# %% [markdown]
# The football data is not specific to a school but rather a record of games.\
# \
# The Basketball data is generated by school and thus we have two representations of the same game based on the school.\
# \
# We need to translate the football data to a similar style.

# %%
# reduce 'df' to football games Michigan played
um = df[(df['home_team'] =='Michigan') | (df['away_team']=='Michigan')].copy() # where Michigan played home or away
um['school'] = 'michigan'
um['opponent'] = um.apply(lambda row: row['away_team'] if row['home_team']=='Michigan' else row['home_team'], axis=1)
um['h_a'] = um.apply(lambda row: 'H' if row['home_team']=='Michigan' else 'A', axis=1) # H if home, A if away

# reduce 'df' to football games Michigan State played
msu = df[(df['home_team']=='Michigan State') | (df['away_team']=='Michigan State')].copy() # where MSU played home or away
msu['school'] = 'michigan state'
msu['opponent'] = msu.apply(lambda row: row['away_team'] if row['home_team']=='Michigan State' else row['home_team'], axis=1)
msu['h_a'] = msu.apply(lambda row: 'H' if row['home_team']=='Michigan State' else 'A', axis=1)

# %%
um_msu = pd.concat([um, msu]) # concatenate 'um', 'msu' together for football DataFrame
um_msu['sport'] = 'football'

# %%
def DetermineResult(h_a, home_points, away_points):
    if h_a == 'H': # if it's home
        if home_points > away_points:
            return 'W'
        elif home_points < away_points:
            return 'L'
        else:
            return 'T'
    else: # if it's away
        if home_points > away_points:
            return 'L'
        elif home_points < away_points:
            return 'W'
        else:
            return 'T'
        

# DetermineResult() for 'W', 'L', 'T'
um_msu['result'] = um_msu.apply(lambda r: DetermineResult(r['h_a'], r['home_points'], r['away_points']), axis=1)

# %%
# always Michigan or Michigan State's points regardless of whether the game was home or away
um_msu['team_points'] = um_msu.apply(lambda r: r['home_points'] if r['h_a'] == 'H' else r['away_points'], axis=1)

# always the opponent's points
um_msu['opp_points'] = um_msu.apply(lambda r: r['home_points'] if r['h_a'] == 'A' else r['away_points'], axis=1)

# %%
# overtime column
um_msu['ot'] = um_msu.apply(lambda r: None if (len(r['home_line_scores']) -  4) == 0 else "OT" , axis=1)

# %% [markdown]
# #### Merging football data together

# %%
# merge Michigan / Michigan State football data w/ Michigan / Michigan State poll data
um_msu = um_msu.merge(cmb_ranks[['rank', 'school', 'season', 'season_type', 'week']], 
                      how='left', 
                      on=['school', 'season', 'week', 'season_type'])
um_msu.opponent = um_msu.opponent.str.lower()

# new column created before merge to set proper rank of opponent
cmb_ranks['opponent_rank'] = cmb_ranks['rank']

# merge opponent data into Michigan / Michigan State DataFrame
um_msu = um_msu.merge(cmb_ranks[['opponent_rank', 'opponent', 'season', 'season_type', 'week']], 
                      how='left', 
                      on=['opponent', 'season', 'week', 'season_type'])

# %%
# um_msu['rank'] = um_msu['rank'].astype('int64')
# um_msu['opponent_rank'] = um_msu['opponent_rank'].astype('int64')

# um_msu[um_msu['rank'].isna() == False]['rank'].unique()

# um_msu[['start_date','home_team','away_team','h_a','home_points','away_points','result','team_points','opp_points','ot']].sample(10)

# %%
print(len(um_msu)) # number of football games played by Michigan and Michigan State over 10 year period
assert len(um_msu) == 267, f"Incorrect number of Michigan/MSU football games, got {len(um_msu)}"
# Out:
# 267

# %%
um_msu[['school', 'rank', 'opponent', 'opponent_rank', 'season', 'week', 'attendance']].sample(10)
# Out:
#              school  rank          opponent  opponent_rank  season  week  \
# 57         michigan   NaN      northwestern            NaN    2013    12
# 197  michigan state   9.0           wyoming            NaN    2014     5
# 91         michigan   2.0    michigan state            NaN    2016     9
# 219  michigan state  12.0            furman            NaN    2016     1
# 206  michigan state   5.0  western michigan            NaN    2015     1
# 115        michigan   6.0    michigan state           24.0    2018     8
# 2          michigan  25.0  eastern michigan            NaN    2009     3
# 265  michigan state   NaN           rutgers            NaN    2019    13
# 245  michigan state  24.0           indiana            NaN    2018     4
# 224  michigan state   NaN      northwestern            NaN    2016     7
#
#      attendance
# 57      47330.0
# 197     74227.0
# 91      75802.0
# 219     74516.0
# 206     30885.0
# 115         0.0
# 2           0.0
# 265     24641.0
# 245         0.0
# 224     75625.0

# %%
um_msu[um_msu['start_date'] == '2012-10-13T16:00:00.000Z'][['home_team','away_team','away_line_scores','ot']]
# Out:
#           home_team away_team     away_line_scores  ot
# 175  Michigan State      Iowa  [0, 3, 0, 10, 3, 3]  OT

# %%
um_msu['start_dt'] = pd.to_datetime(um_msu['start_date']) # convert to datetime
um_msu['end_inc_window'] = um_msu['start_dt'] + pd.to_timedelta(11, unit='h') # set incident time window from game start time

# %%
um_msu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 267 entries, 0 to 266
# Data columns (total 42 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  267 non-null    int64
#  1   season              267 non-null    int64
#  2   week                267 non-null    int64
#  3   season_type         267 non-null    object
#  4   start_date          267 non-null    object
#  5   start_time_tbd      0 non-null      float64
#  6   neutral_site        267 non-null    bool
#  7   conference_game     267 non-null    bool
#  8   attendance          267 non-null    float64
#  9   venue_id            263 non-null    float64
#  10  venue               263 non-null    object
#  11  home_id             267 non-null    int64
#  12  home_team           267 non-null    object
#  13  home_conference     267 non-null    object
#  14  home_points         267 non-null    int64
#  15  home_line_scores    267 non-null    object
#  16  home_post_win_prob  243 non-null    float64
#  17  home_pregame_elo    260 non-null    float64
#  18  home_postgame_elo   260 non-null    float64
#  19  away_id             267 non-null    int64
#  20  away_team           267 non-null    object
#  21  away_conference     259 non-null    object
#  22  away_points         267 non-null    int64
#  23  away_line_scores    267 non-null    object
#  24  away_post_win_prob  243 non-null    float64
#  25  away_pregame_elo    260 non-null    float64
#  26  away_postgame_elo   260 non-null    float64
#  27  excitement_index    219 non-null    float64
#  28  highlights          96 non-null     object
#  29  notes               0 non-null      object
#  30  school              267 non-null    object
#  31  opponent            267 non-null    object
#  32  h_a                 267 non-null    object
#  33  sport               267 non-null    object
#  34  result              267 non-null    object
#  35  team_points         267 non-null    int64
#  36  opp_points          267 non-null    int64
#  37  ot                  16 non-null     object
#  38  rank                161 non-null    float64
#  39  opponent_rank       80 non-null     float64
#  40  start_dt            267 non-null    datetime64[ns, UTC]
#  41  end_inc_window      267 non-null    datetime64[ns, UTC]
# dtypes: bool(2), datetime64[ns, UTC](2), float64(12), int64(9), object(17)
# memory usage: 86.0+ KB

# %%
# drop columns - reduce from 42 columns to 14
um_msu = um_msu[['school', 'sport', 'start_dt', 'season_type', 'opponent', 'result', 'team_points', 
                 'opp_points', 'ot', 'rank', 'opponent_rank', 'end_inc_window', 'attendance', 'venue', 'excitement_index']]
um_msu.columns
# Out:
# Index(['school', 'sport', 'start_dt', 'season_type', 'opponent', 'result',
#        'team_points', 'opp_points', 'ot', 'rank', 'opponent_rank',
#        'end_inc_window', 'attendance', 'venue', 'excitement_index'],
#       dtype='object')

# %% [markdown]
# ### Basketball Data

# %%
# Read in college basketball data and match column names w/ football before merge

cbb = pd.read_csv('../04_finaldata/df_basketball_final.csv', parse_dates=['start_dt', 'end_inc_window'])

# %%
# drop columns
cbb = cbb[['school', 'sport', 'start_dt', 'type', 
           'opponent', 'result', 'team_points', 'opp_points', 
           'ot', 'rank', 'opponent_rank', 'end_inc_window']]

# %%
# text formatting
cbb = cbb.rename({'type': 'season_type'}, axis=1)
cbb['opponent'] = cbb['opponent'].str.lower()
cbb['season_type'] = cbb['season_type'].apply(lambda x: "regular" if x=='REG' else x)
cbb.columns
# fbb = spark.createDataFrame(um_msu[['school','sport','game_dt','season_type','opponent','result','team_points','opp_points','ot','end_inc_window']])
# Out:
# Index(['school', 'sport', 'start_dt', 'season_type', 'opponent', 'result',
#        'team_points', 'opp_points', 'ot', 'rank', 'opponent_rank',
#        'end_inc_window'],
#       dtype='object')

# %% [markdown]
# #### Final sports merge

# %%
# We join the football and basketball data and do some manipulation across the sports including binarizing results and OT, 
# cleaning up / naming the indexes (used for a unique key)
cbb.school = cbb.school.replace({'michigan-state':'michigan state'})
sports = pd.concat([um_msu, cbb])
sports['ot'] = sports.ot.replace([np.nan], [None])
sports['ot'] = sports.ot.replace({None: 0, "OT": 1, "2OT": 1})
sports['result'] = sports.result.replace({"W": 1,"L": 0})
sports = sports.reset_index(drop=True)
sports.index.names = ['game_id']
sports
# Out:
#                  school       sport                   start_dt season_type  \
# game_id
# 0              michigan    football  2009-09-05 19:30:00+00:00     regular
# 1              michigan    football  2009-09-12 19:30:00+00:00     regular
# 2              michigan    football  2009-09-19 16:00:00+00:00     regular
# 3              michigan    football  2009-09-26 16:00:00+00:00     regular
# 4              michigan    football  2009-10-03 16:00:00+00:00     regular
# ...                 ...         ...                        ...         ...
# 988      michigan state  basketball        2019-03-21 14:45:00        NCAA
# 989      michigan state  basketball        2019-03-23 19:45:00        NCAA
# 990      michigan state  basketball        2019-03-29 19:00:00        NCAA
# 991      michigan state  basketball        2019-03-31 17:05:00        NCAA
# 992      michigan state  basketball        2019-04-06 20:49:00        NCAA
#
#                      opponent  result  team_points  opp_points  ot  rank  \
# game_id
# 0            western michigan       1           31           7   0   NaN
# 1                  notre dame       1           38          34   0   NaN
# 2            eastern michigan       1           45          17   0  25.0
# 3                     indiana       1           36          33   0  23.0
# 4              michigan state       0           20          26   1  22.0
# ...                       ...     ...          ...         ...  ..   ...
# 988                   bradley       1           76          65   0   NaN
# 989                 minnesota       1           70          50   0   NaN
# 990      louisiana state (12)       1           80          63   0   NaN
# 991                  duke (1)       1           68          67   0   NaN
# 992            texas tech (9)       0           51          61   0   NaN
#
#          opponent_rank             end_inc_window  attendance  \
# game_id
# 0                  NaN  2009-09-06 06:30:00+00:00         0.0
# 1                 18.0  2009-09-13 06:30:00+00:00         0.0
# 2                  NaN  2009-09-20 03:00:00+00:00         0.0
# 3                  NaN  2009-09-27 03:00:00+00:00         0.0
# 4                  NaN  2009-10-04 03:00:00+00:00         0.0
# ...                ...                        ...         ...
# 988                NaN        2019-03-22 00:45:00         NaN
# 989                NaN        2019-03-24 05:45:00         NaN
# 990               12.0        2019-03-30 05:00:00         NaN
# 991                1.0        2019-04-01 03:05:00         NaN
# 992                9.0        2019-04-07 06:49:00         NaN
#
#                     venue  excitement_index
# game_id
# 0        Michigan Stadium               NaN
# 1        Michigan Stadium               NaN
# 2        Michigan Stadium               NaN
# 3        Michigan Stadium               NaN
# 4         Spartan Stadium               NaN
# ...                   ...               ...
# 988                   NaN               NaN
# 989                   NaN               NaN
# 990                   NaN               NaN
# 991                   NaN               NaN
# 992                   NaN               NaN
#
# [993 rows x 15 columns]

# %%
sports.columns # verify our columms
# Out:
# Index(['school', 'sport', 'start_dt', 'season_type', 'opponent', 'result',
#        'team_points', 'opp_points', 'ot', 'rank', 'opponent_rank',
#        'end_inc_window', 'attendance', 'venue', 'excitement_index'],
#       dtype='object')

# %%
# Reduce number of columns that will be used in our analysis (prior to join with incident data)
sports = sports[['school', 'sport', 'start_dt', 'season_type', 'opponent', 'result', 'team_points',
                 'opp_points', 'ot', 'rank', 'opponent_rank', 'end_inc_window', 'attendance', 'venue', 'excitement_index']]

# %%
sports.season_type.unique()
# Out:
# array(['regular', 'CTOURN', 'NCAA'], dtype=object)

# %%
print(len(sports)) # 726 basketball games + 267 football games
assert len(sports) == 993, f"Incorrect number of football + basketball games, got {len(sports)}, should be 267 football games + 726 basketball games"
# Out:
# 993

# %%
sports.to_csv('../04_finaldata/sports.csv', header=True)

# %% [markdown]
# <a id='join'></a>

# %% [markdown]
# &nbsp;
#
# ## Join Sports and Incidents via Spark SQL
#
# Now that the sports and incident data are manipulated, we'll use Spark SQL to create a dataset of all the games and their associated incidents / offenses.\
# \
# We'll ultimately end up with a large table that identifies every offense and its attribution to a particular incident and game.

# %% [markdown]
# #### sportrdd

# %%
from pyspark.sql.types import TimestampType
from pyspark.sql.functions import col
from pyspark.sql import SparkSession
spark = SparkSession \
    .builder \
    .master("local[*]") \
    .appName('Merge') \
    .getOrCreate() 

sc = spark.sparkContext

# %%
# Convert the sports DataFrame from prior step into a Spark DataFrame and ensure dates are casted correctly

sportsrdd = spark.read.csv('../04_finaldata/sports.csv', header=True, inferSchema=True)
sportsrdd = sportsrdd.withColumn('start_dt', col('start_dt').cast(TimestampType())) # convert start_dt to Timestamp
sportsrdd = sportsrdd.withColumn('end_inc_window', col('end_inc_window').cast(TimestampType())) # convert end_inc_window to Timestamp

# %%
print(sportsrdd.count())
sportsrdd.printSchema()
# Out:
# 993
# root
#  |-- game_id: integer (nullable = true)
#  |-- school: string (nullable = true)
#  |-- sport: string (nullable = true)
#  |-- start_dt: timestamp (nullable = true)
#  |-- season_type: string (nullable = true)
#  |-- opponent: string (nullable = true)
#  |-- result: integer (nullable = true)
#  |-- team_points: integer (nullable = true)
#  |-- opp_points: integer (nullable = true)
#  |-- ot: integer (nullable = true)
#  |-- rank: string (nullable = true)
#  |-- opponent_rank: double (nullable = true)
#  |-- end_inc_window: timestamp (nullable = true)
#  |-- attendance: double (nullable = true)
#  |-- venue: string (nullable = true)
#  |-- excitement_index: double (nullable = true)

# %%
# Let's run a quick test to see that the columns came over properly
test = sportsrdd.sample(withReplacement=False, fraction=.1)
test.show(5)
# Out:
# +-------+--------+--------+-------------------+-----------+----------------+------+-----------+----------+---+----+-------------+-------------------+----------+----------------+----------------+
# |game_id|  school|   sport|           start_dt|season_type|        opponent|result|team_points|opp_points| ot|rank|opponent_rank|     end_inc_window|attendance|           venue|excitement_index|
# +-------+--------+--------+-------------------+-----------+----------------+------+-----------+----------+---+----+-------------+-------------------+----------+----------------+----------------+
# |      5|michigan|football|2009-10-10 20:05:00|    regular|            iowa|     0|         28|        30|  0|null|         12.0|2009-10-11 07:05:00|       0.0| Kinnick Stadium|            null|
# |     11|michigan|football|2009-11-21 12:00:00|    regular|      ohio state|     0|         10|        21|  0|null|         10.0|2009-11-21 23:00:00|       0.0|Michigan Stadium|            null|
# |     24|michigan|football|2011-09-03 15:30:00|    regular|western michigan|     1|         34|        10|  1|null|         null|2011-09-04 02:30:00|       0.0|Michigan Stadium|3.41170313976107|
# |     26|michigan|football|2011-09-17 12:00:00|    regular|eastern michigan|     1|         31|         3|  0|null|         null|2011-09-17 23:00:00|       0.0|Michigan Stadium|3.28899566344527|
# |     28|michigan|football|2011-10-01 12:00:00|    regular|       minnesota|     1|         58|         0|  0|19.0|         null|2011-10-01 23:00:00|       0.0|Michigan Stadium|4.83738216735322|
# +-------+--------+--------+-------------------+-----------+----------------+------+-----------+----------+---+----+-------------+-------------------+----------+----------------+----------------+
# only showing top 5 rows

# %% [markdown]
# #### Incident Spark DataFrame

# %%
# Let's get the incident data for UM and MSU and do the same thing with the dates
incs = spark.read.csv('../04_finaldata/UM_MSU_Offs.csv', header=True, inferSchema=True)
incs = incs.withColumn('INCIDENT_DATE', col('INCIDENT_DATE').cast(TimestampType())) # convert 'INCIDENT_DATE' to Timestamp type

# %%
assert incs.count() == 97009, "Incorrect number of incidents - check 03_eda_baseline_analysis.ipynb for correct number"

# %%
# Create Spark SQL Table Views from both RDDs
sportsrdd.createOrReplaceTempView("sports")
incs.createOrReplaceTempView("incs")

# %%
sportsrdd.printSchema()
# Out:
# root
#  |-- game_id: integer (nullable = true)
#  |-- school: string (nullable = true)
#  |-- sport: string (nullable = true)
#  |-- start_dt: timestamp (nullable = true)
#  |-- season_type: string (nullable = true)
#  |-- opponent: string (nullable = true)
#  |-- result: integer (nullable = true)
#  |-- team_points: integer (nullable = true)
#  |-- opp_points: integer (nullable = true)
#  |-- ot: integer (nullable = true)
#  |-- rank: string (nullable = true)
#  |-- opponent_rank: double (nullable = true)
#  |-- end_inc_window: timestamp (nullable = true)
#  |-- attendance: double (nullable = true)
#  |-- venue: string (nullable = true)
#  |-- excitement_index: double (nullable = true)

# %%
# We need to get a list of every incident / offense associated to a game
# This grabs columns from 'sports' pandas DataFrame and the 'incs' Spark DataFrame and saves into a Spark DataFrame

query = """

SELECT
    s.game_id,
    s.sport, 
    s.school, 
    s.start_dt, 
    s.end_inc_window,
    s.rank,
    s.season_type,
    s.opponent,
    s.opponent_rank,
    s.result,
    s.team_points,
    s.opp_points,
    s.ot,
    s.attendance, 
    i.INCIDENT_ID as incident_id,
    i.OFFENSE_ID as offense_id,
    i.OFFENSE_NAME as offense_name,
    i.INCIDENT_DATE as incident_date

FROM
    sports s,
    incs i

WHERE
    i.INCIDENT_DATE BETWEEN s.start_dt AND s.end_inc_window AND
    i.school = s.school
"""


result = spark.sql(query)

# %%
df = result.toPandas() # convert Spark DataFrame to pandas DataFrame
print(df.shape)
df.head()
# Out:
# (6690, 18)
#    game_id     sport    school            start_dt      end_inc_window  rank  \
# 0        0  football  michigan 2009-09-05 15:30:00 2009-09-06 02:30:00  None
# 1        0  football  michigan 2009-09-05 15:30:00 2009-09-06 02:30:00  None
# 2        0  football  michigan 2009-09-05 15:30:00 2009-09-06 02:30:00  None
# 3        0  football  michigan 2009-09-05 15:30:00 2009-09-06 02:30:00  None
# 4        0  football  michigan 2009-09-05 15:30:00 2009-09-06 02:30:00  None
#
#   season_type          opponent  opponent_rank  result  team_points  \
# 0     regular  western michigan            NaN       1           31
# 1     regular  western michigan            NaN       1           31
# 2     regular  western michigan            NaN       1           31
# 3     regular  western michigan            NaN       1           31
# 4     regular  western michigan            NaN       1           31
#
#    opp_points  ot  attendance  incident_id  offense_id  \
# 0           7   0         0.0     50917845    55723958
# 1           7   0         0.0     50954457    55757376
# 2           7   0         0.0     50917864    55728651
# 3           7   0         0.0     50917837    55728647
# 4           7   0         0.0     50917882    55725838
#
#                                  offense_name       incident_date
# 0                                 Shoplifting 2009-09-05 20:00:00
# 1                              Pocket-picking 2009-09-05 16:00:00
# 2  Credit Card/Automated Teller Machine Fraud 2009-09-05 20:00:00
# 3    Destruction/Damage/Vandalism of Property 2009-09-05 20:00:00
# 4    Destruction/Damage/Vandalism of Property 2009-09-05 20:00:00

# %%
assert df.shape[0] == 6690, "Incorrect number of joined rows between Sport RDD and Incident Spark DataFrame"

# %%
len(df.game_id.unique()) # check how many unique games had some type of incident associated to them
# Out:
# 953

# %%
df.isna().sum()
# Out:
# game_id              0
# sport                0
# school               0
# start_dt             0
# end_inc_window       0
# rank              1542
# season_type          0
# opponent             0
# opponent_rank     4489
# result               0
# team_points          0
# opp_points           0
# ot                   0
# attendance        3636
# incident_id          0
# offense_id           0
# offense_name         0
# incident_date        0
# dtype: int64

# %% [markdown]
# Now, since we performed an SQL operation that returned results that matched our criteria, we need to join these results to the games dataset.\
# \
# We'll create another table view and call it `game_incs` and use a left join to the sports data.

# %%
result.createOrReplaceTempView('game_incs')

# %%
query2 = """

SELECT s.*, g.incident_id, g.offense_id, g.offense_name, g.incident_date

FROM
    sports s LEFT JOIN game_incs g
    ON s.game_id = g.game_id
    
"""

result2 = spark.sql(query2)

# %%
full = result2.toPandas().set_index('game_id')

# %%
len(full.index.unique()), full.shape
# Out:
# (993, (6730, 19))

# %%
assert full.shape[0] == 6730, "Incorrect number of incidents joined to game_id values"

# %%
full.isna().sum() # na values mostly from games where no incidents occurred w/in time window
# Out:
# school                 0
# sport                  0
# start_dt               0
# season_type            0
# opponent               0
# result                 0
# team_points            0
# opp_points             0
# ot                     0
# rank                1542
# opponent_rank       4521
# end_inc_window         0
# attendance          3673
# venue               3736
# excitement_index    4278
# incident_id           40
# offense_id            40
# offense_name          40
# incident_date         40
# dtype: int64

# %% [markdown]
# <a id='check'></a>

# %% [markdown]
# &nbsp;
#
# ## Checking the full DataFrame

# %%
full.sample(20)
# Out:
#                  school       sport            start_dt season_type  \
# game_id
# 367            michigan  basketball 2012-03-16 18:20:00        NCAA
# 38             michigan    football 2012-09-15 15:30:00     regular
# 850      michigan state  basketball 2015-11-17 22:00:00     regular
# 330            michigan  basketball 2011-03-11 14:30:00      CTOURN
# 702      michigan state  basketball 2011-11-20 18:00:00     regular
# 689      michigan state  basketball 2011-02-15 21:00:00     regular
# 685      michigan state  basketball 2011-01-30 18:00:00     regular
# 21             michigan    football 2010-11-13 12:00:00     regular
# 67             michigan    football 2014-10-25 15:30:00     regular
# 93             michigan    football 2016-11-12 20:00:00     regular
# 223      michigan state    football 2016-10-08 15:30:00     regular
# 160      michigan state    football 2011-10-01 15:30:00     regular
# 424            michigan  basketball 2014-01-22 19:00:00     regular
# 8              michigan    football 2009-10-31 15:30:00     regular
# 296            michigan  basketball 2010-03-07 16:00:00     regular
# 357            michigan  basketball 2012-02-05 13:00:00     regular
# 216      michigan state    football 2015-11-21 15:30:00     regular
# 10             michigan    football 2009-11-14 12:00:00     regular
# 411            michigan  basketball 2013-11-22 18:00:00     regular
# 856      michigan state  basketball 2015-12-02 19:15:00     regular
#
#                     opponent  result  team_points  opp_points  ot  rank  \
# game_id
# 367                     ohio       0           60          65   0  None
# 38                     umass       1           63          13   0  17.0
# 850               kansas (4)       1           79          73   0    13
# 330                 illinois       1           60          55   0     -
# 702              little rock       1           69          47   0     -
# 689           ohio state (2)       0           61          71   0     -
# 685                  indiana       1           84          83   1    25
# 21                    purdue       1           27          16   0  None
# 67            michigan state       0           11          35   0  None
# 93                      iowa       0           13          14   0   3.0
# 223                      byu       0           14          31   0  None
# 160               ohio state       1           10           7   0  None
# 424                iowa (10)       1           75          67   0    21
# 8                   illinois       0           13          38   0  None
# 296      michigan state (11)       0           48          64   0     -
# 357       michigan state (9)       0           54          64   0    23
# 216               ohio state       1           17          14   0   9.0
# 10                 wisconsin       0           24          45   0  None
# 411            florida state       1           82          80   1    15
# 856          louisville (24)       1           71          67   0     3
#
#          opponent_rank      end_inc_window  attendance                 venue  \
# game_id
# 367                NaN 2012-03-17 04:20:00         NaN                  None
# 38                 NaN 2012-09-16 02:30:00    110708.0      Michigan Stadium
# 850                4.0 2015-11-18 08:00:00         NaN                  None
# 330                NaN 2011-03-12 00:30:00         NaN                  None
# 702                NaN 2011-11-21 04:00:00         NaN                  None
# 689                2.0 2011-02-16 07:00:00         NaN                  None
# 685                NaN 2011-01-31 04:00:00         NaN                  None
# 21                 NaN 2010-11-13 23:00:00         0.0      Ross-Ade Stadium
# 67                 8.0 2014-10-26 02:30:00     76331.0       Spartan Stadium
# 93                 NaN 2016-11-13 07:00:00     70585.0       Kinnick Stadium
# 223                NaN 2016-10-09 02:30:00     74214.0       Spartan Stadium
# 160                NaN 2011-10-02 02:30:00         0.0          Ohio Stadium
# 424               10.0 2014-01-23 05:00:00         NaN                  None
# 8                  NaN 2009-11-01 01:30:00         0.0      Memorial Stadium
# 296               11.0 2010-03-08 02:00:00         NaN                  None
# 357                9.0 2012-02-05 23:00:00         NaN                  None
# 216                3.0 2015-11-22 02:30:00    108975.0          Ohio Stadium
# 10                20.0 2009-11-14 23:00:00         0.0  Camp Randall Stadium
# 411                NaN 2013-11-23 04:00:00         NaN                  None
# 856               24.0 2015-12-03 05:15:00         NaN                  None
#
#          excitement_index  incident_id  offense_id  \
# game_id
# 367                   NaN   64736525.0  68683402.0
# 38               2.029581   64753997.0  68701870.0
# 850                   NaN   81417366.0  89053926.0
# 330                   NaN   59271742.0  62411268.0
# 702                   NaN   60150490.0  62386759.0
# 689                   NaN   60144732.0  62385870.0
# 685                   NaN   60072366.0  66485711.0
# 21                    NaN   55953625.0  57592702.0
# 67               1.376870   74922684.0  81328753.0
# 93               5.953105   88537941.0  96895297.0
# 223              4.975837   90503986.0  99147771.0
# 160              4.907769   60080973.0  66502250.0
# 424                   NaN   74903697.0  81313924.0
# 8                     NaN   50955514.0  55778201.0
# 296                   NaN   55930499.0  57572374.0
# 357                   NaN   64763445.0  68711339.0
# 216              6.578976   81418127.0  89047075.0
# 10                    NaN   50923659.0  55730638.0
# 411                   NaN   69027004.0  75190231.0
# 856                   NaN   81354308.0  86293897.0
#
#                                         offense_name       incident_date
# game_id
# 367                                   Simple Assault 2012-03-16 23:00:00
# 38                          Drug/Narcotic Violations 2012-09-15 17:00:00
# 850                              Theft From Building 2015-11-18 07:00:00
# 330                         Drug/Narcotic Violations 2011-03-12 00:00:00
# 702                                All Other Larceny 2011-11-20 18:00:00
# 689                              Theft From Building 2011-02-15 21:00:00
# 685         Destruction/Damage/Vandalism of Property 2011-01-31 02:00:00
# 21                          Stolen Property Offenses 2010-11-13 19:00:00
# 67                               Motor Vehicle Theft 2014-10-25 20:00:00
# 93                               Theft From Building 2016-11-13 00:00:00
# 223                         Theft From Motor Vehicle 2016-10-08 19:00:00
# 160         Destruction/Damage/Vandalism of Property 2011-10-01 20:00:00
# 424                                      Shoplifting 2014-01-22 21:00:00
# 8           Destruction/Damage/Vandalism of Property 2009-10-31 23:00:00
# 296                              Theft From Building 2010-03-08 00:00:00
# 357      Theft of Motor Vehicle Parts or Accessories 2012-02-05 17:00:00
# 216                     Burglary/Breaking & Entering 2015-11-22 00:00:00
# 10          Destruction/Damage/Vandalism of Property 2009-11-14 22:00:00
# 411                               Aggravated Assault 2013-11-23 00:00:00
# 856                                   Simple Assault 2015-12-03 02:00:00

# %%
full[(full['school']=='michigan state') & (full['sport']=='basketball')]
# Out:
#                  school       sport            start_dt season_type  \
# game_id
# 833      michigan state  basketball 2015-02-10 19:00:00     regular
# 737      michigan state  basketball 2012-11-13 20:30:00     regular
# 737      michigan state  basketball 2012-11-13 20:30:00     regular
# 737      michigan state  basketball 2012-11-13 20:30:00     regular
# 858      michigan state  basketball 2015-12-09 19:00:00     regular
# ...                 ...         ...                 ...         ...
# 963      michigan state  basketball 2018-12-08 12:00:00     regular
# 954      michigan state  basketball 2018-11-06 19:00:00     regular
# 954      michigan state  basketball 2018-11-06 19:00:00     regular
# 954      michigan state  basketball 2018-11-06 19:00:00     regular
# 954      michigan state  basketball 2018-11-06 19:00:00     regular
#
#                        opponent  result  team_points  opp_points  ot rank  \
# game_id
# 833                northwestern       1           68          44   0    -
# 737                  kansas (7)       1           67          64   0   21
# 737                  kansas (7)       1           67          64   0   21
# 737                  kansas (7)       1           67          64   0   21
# 858      maryland-eastern shore       1           78          35   0    1
# ...                         ...     ...          ...         ...  ..  ...
# 963                     florida       1           63          59   0   10
# 954                  kansas (1)       0           87          92   0   10
# 954                  kansas (1)       0           87          92   0   10
# 954                  kansas (1)       0           87          92   0   10
# 954                  kansas (1)       0           87          92   0   10
#
#          opponent_rank      end_inc_window  attendance venue  \
# game_id
# 833                NaN 2015-02-11 05:00:00         NaN  None
# 737                7.0 2012-11-14 06:30:00         NaN  None
# 737                7.0 2012-11-14 06:30:00         NaN  None
# 737                7.0 2012-11-14 06:30:00         NaN  None
# 858                NaN 2015-12-10 05:00:00         NaN  None
# ...                ...                 ...         ...   ...
# 963                NaN 2018-12-08 22:00:00         NaN  None
# 954                1.0 2018-11-07 05:00:00         NaN  None
# 954                1.0 2018-11-07 05:00:00         NaN  None
# 954                1.0 2018-11-07 05:00:00         NaN  None
# 954                1.0 2018-11-07 05:00:00         NaN  None
#
#          excitement_index  incident_id   offense_id              offense_name  \
# game_id
# 833                   NaN          NaN          NaN                      None
# 737                   NaN   66991130.0   69033726.0  Drug/Narcotic Violations
# 737                   NaN   66991129.0   69033725.0       Theft From Building
# 737                   NaN   66910632.0   68926517.0            Simple Assault
# 858                   NaN   81355133.0   86293754.0  Theft From Motor Vehicle
# ...                   ...          ...          ...                       ...
# 963                   NaN  102879319.0  126709921.0         All Other Larceny
# 954                   NaN  101773494.0  125445404.0       Theft From Building
# 954                   NaN  101779877.0  125449009.0         All Other Larceny
# 954                   NaN  101774189.0  125451561.0  Drug/Narcotic Violations
# 954                   NaN  114283403.0  139524213.0            Simple Assault
#
#               incident_date
# game_id
# 833                     NaT
# 737     2012-11-14 00:00:00
# 737     2012-11-13 22:00:00
# 737     2012-11-13 21:00:00
# 858     2015-12-10 02:00:00
# ...                     ...
# 963     2018-12-08 16:00:00
# 954     2018-11-07 00:00:00
# 954     2018-11-06 19:00:00
# 954     2018-11-06 19:00:00
# 954     2018-11-06 22:00:00
#
# [1380 rows x 19 columns]

# %%
# Quick calculation to determine the number of sporting events that have an actual incident associated to them
grp = full.groupby('start_dt')[['incident_id','offense_name']].count()
print('{:.3f}'.format(grp[grp['incident_id'] > 0].shape[0] / 993))
# Out:
# 0.899

# %%
full.to_csv('../04_finaldata/full_data.csv') # DataFrame to be used for main report analysis

# %%
# Let's do a quick validation to make sure that the data associated ok. Take the game start_date with the highest number of incidents and check what offenses were created. Validate that we have the same number.
grp.sort_values('incident_id', ascending=False)
# Out:
#                      incident_id  offense_name
# start_dt
# 2014-10-25 15:30:00           53            53
# 2011-10-15 12:00:00           49            49
# 2016-10-29 12:00:00           46            46
# 2013-11-02 15:30:00           41            41
# 2009-10-03 12:00:00           40            40
# ...                          ...           ...
# 2015-11-23 19:00:00            0             0
# 2016-12-30 18:00:00            0             0
# 2015-02-22 19:30:00            0             0
# 2009-12-10 19:00:00            0             0
# 2016-12-27 21:00:00            0             0
#
# [929 rows x 2 columns]

# %%
# Seeing 10-25-2014 has the highest number of offenses.  Let's see what incidents/offenses were generated
testsql = "SELECT i.school, i.INCIDENT_ID,i.OFFENSE_NAME FROM incs i WHERE i.INCIDENT_DATE BETWEEN '2014-10-25 15:30:00' AND '2014-10-26 2:30:00'"
r = spark.sql(testsql)
r.show(50)
# Out:
# +--------------+-----------+--------------------+
# |        school|INCIDENT_ID|        OFFENSE_NAME|
# +--------------+-----------+--------------------+
# |michigan state|   73350634| Theft From Building|
# |michigan state|   73418637|      Simple Assault|
# |michigan state|   73351423|      Simple Assault|
# |michigan state|   73418636|      Simple Assault|
# |michigan state|   73350593|Destruction/Damag...|
# |      michigan|   74955897| Theft From Building|
# |michigan state|   73350592|  Aggravated Assault|
# |michigan state|   73418625|      Simple Assault|
# |michigan state|   73418627|Destruction/Damag...|
# |michigan state|   73350608|Burglary/Breaking...|
# |michigan state|   73350599|Destruction/Damag...|
# |michigan state|   73350583|  Aggravated Assault|
# |michigan state|   73418618|      Simple Assault|
# |michigan state|   73418619|      Simple Assault|
# |michigan state|   73350603| Motor Vehicle Theft|
# |      michigan|   74955899|Drug/Narcotic Vio...|
# |michigan state|   73418617|  Aggravated Assault|
# |      michigan|   74922685|      Simple Assault|
# |michigan state|   73350585|Destruction/Damag...|
# |michigan state|   73350587|Destruction/Damag...|
# |      michigan|   74922684| Motor Vehicle Theft|
# |      michigan|   74923352|        Embezzlement|
# |michigan state|   73350590|             Robbery|
# |michigan state|   73419507| Theft From Building|
# |michigan state|   73418620|      Simple Assault|
# |michigan state|   73350615|Credit Card/Autom...|
# |michigan state|   73350584|Destruction/Damag...|
# |michigan state|   73418616|Destruction/Damag...|
# |      michigan|   74922693|   All Other Larceny|
# |      michigan|   74955896| Theft From Building|
# |michigan state|   73418623|      Simple Assault|
# |michigan state|   73350582|Destruction/Damag...|
# |michigan state|   73350620| Theft From Building|
# |michigan state|   73350596|  Aggravated Assault|
# |michigan state|   73351407|Stolen Property O...|
# |michigan state|   73350607|Burglary/Breaking...|
# |michigan state|   73351416|Credit Card/Autom...|
# |michigan state|   73350595|Burglary/Breaking...|
# |michigan state|   73350598|   All Other Larceny|
# |michigan state|   73350594|               Arson|
# |michigan state|   73350595|  Aggravated Assault|
# |michigan state|   73350616|Destruction/Damag...|
# |      michigan|   74922686|      Simple Assault|
# |michigan state|   73350600| Extortion/Blackmail|
# |michigan state|   73350618|             Robbery|
# |michigan state|   73350613| Motor Vehicle Theft|
# |      michigan|   74929451|Destruction/Damag...|
# |michigan state|   73350618|Credit Card/Autom...|
# |michigan state|   73350618|Stolen Property O...|
# |michigan state|   73350602|Destruction/Damag...|
# +--------------+-----------+--------------------+
# only showing top 50 rows

# %%
assert r.count() == 53, "Incorrect number of incidents for Michigan vs. Michigan State 2014"

# %% [markdown]
# ^\
# |
#
# Looks like 53 offenses - most attributed to MSU's campus (assault).\
# \
# This was a game where Michigan State and played Michigan and won, btw. It was played at Spartan Stadium.

# %% [markdown]
# &nbsp;
#
# ## Result checks

# %%
sports.columns
# Out:
# Index(['school', 'sport', 'start_dt', 'season_type', 'opponent', 'result',
#        'team_points', 'opp_points', 'ot', 'rank', 'opponent_rank',
#        'end_inc_window', 'attendance', 'venue', 'excitement_index'],
#       dtype='object')

# %%
test_query = """SELECT s.school home, s.opponent, s.start_dt start, s.end_inc_window end
                FROM sports s
                WHERE s.school == 'michigan'"""
spark.sql(test_query).show(3)
# Out:
# +--------+----------------+-------------------+-------------------+
# |    home|        opponent|              start|                end|
# +--------+----------------+-------------------+-------------------+
# |michigan|western michigan|2009-09-05 15:30:00|2009-09-06 02:30:00|
# |michigan|      notre dame|2009-09-12 15:30:00|2009-09-13 02:30:00|
# |michigan|eastern michigan|2009-09-19 12:00:00|2009-09-19 23:00:00|
# +--------+----------------+-------------------+-------------------+
# only showing top 3 rows

# %%
# Determine if number of incidents for a game matches on Timestamp alone
test_query = """SELECT i.INCIDENT_ID id 
                FROM incs i 
                WHERE i.INCIDENT_DATE BETWEEN '2009-09-12 15:30:00' AND '2009-09-13 02:30:00'"""
spark.sql(test_query).count()
# Out:
# 35

# %%
test_query = """SELECT s.school home, s.opponent, i.INCIDENT_ID id, i.OFFENSE_NAME offense
                FROM sports s, incs i
                WHERE (s.sport == 'football' 
                        AND s.school == 'michigan' 
                        AND s.opponent == 'notre dame' 
                        AND i.INCIDENT_DATE BETWEEN '2012-01-01 00:00:00' AND '2012-12-31 23:59:59')"""
spark.sql(test_query).count()
# Out:
# 76184

# %%
df_full = pd.read_csv('../04_finaldata/full_data.csv', parse_dates=['start_dt', 'end_inc_window'])
