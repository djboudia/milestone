# %%
import pandas as pd
import glob, os

# %%
directory = r'C:\Users\RJ\OneDrive\education\mads\591_592\milestone\02_sport_rawdata\cfbd_games_json\\'
source_type = r'directory' # directory, .csv, or .xlsx
df = pd.concat(map(lambda file: pd.read_json(file), glob.glob(os.path.join('', directory + '*.json'))))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8966 entries, 0 to 847
# Data columns (total 30 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  8966 non-null   int64
#  1   season              8966 non-null   int64
#  2   week                8966 non-null   int64
#  3   season_type         8966 non-null   object
#  4   start_date          8966 non-null   object
#  5   start_time_tbd      0 non-null      float64
#  6   neutral_site        8966 non-null   bool
#  7   conference_game     8966 non-null   bool
#  8   attendance          8963 non-null   float64
#  9   venue_id            8821 non-null   float64
#  10  venue               8821 non-null   object
#  11  home_id             8966 non-null   int64
#  12  home_team           8966 non-null   object
#  13  home_conference     8955 non-null   object
#  14  home_points         8966 non-null   int64
# ...

# %%
df.tail()
# Out:
#             id  season  week season_type                start_date  \
# 843  401132979    2019    15     regular  2019-12-07T21:00:00.000Z
# 844  401132981    2019    15     regular  2019-12-07T21:00:00.000Z
# 845  401132975    2019    15     regular  2019-12-08T00:30:00.000Z
# 846  401132983    2019    15     regular  2019-12-08T01:00:00.000Z
# 847  401114335    2019    15     regular  2019-12-14T20:00:00.000Z
#
#      start_time_tbd  neutral_site  conference_game  attendance  venue_id  ...  \
# 843             NaN         False             True     23561.0    3653.0  ...
# 844             NaN          True             True     74150.0    5348.0  ...
# 845             NaN          True             True     66810.0    3628.0  ...
# 846             NaN          True             True     66649.0    3812.0  ...
# 847             NaN          True            False         NaN    3806.0  ...
#
#       away_team   away_conference away_points away_line_scores  \
# ...

# %%
directory = r'C:\Users\RJ\OneDrive\education\mads\591_592\milestone\02_sport_rawdata\cfbd_poll_json\\'
source_type = r'directory' # directory, .csv, or .xlsx
df_poll = pd.concat(map(lambda file: pd.read_json(file, orient='records'), glob.glob(os.path.join('', directory + '*.json'))))

# %%
df_poll.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 168 entries, 0 to 15
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      168 non-null    int64
#  1   seasonType  168 non-null    object
#  2   week        168 non-null    int64
#  3   polls       168 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 6.6+ KB

# %%
df_poll.reset_index(inplace=True, drop=True)
df_poll[0:25]
# Out:
#     season seasonType  week                                              polls
# 0     2009    regular    15  [{'poll': 'Coaches Poll', 'ranks': [{'rank': 2...
# 1     2009    regular    12  [{'poll': 'Coaches Poll', 'ranks': [{'rank': 1...
# 2     2009    regular    11  [{'poll': 'Coaches Poll', 'ranks': [{'rank': 2...
# 3     2009    regular    10  [{'poll': 'Coaches Poll', 'ranks': [{'rank': 2...
# 4     2009    regular     8  [{'poll': 'BCS Standings', 'ranks': [{'rank': ...
# 5     2009    regular     6  [{'poll': 'Coaches Poll', 'ranks': [{'rank': 2...
# 6     2009    regular    14  [{'poll': 'Coaches Poll', 'ranks': [{'rank': 1...
# 7     2009    regular    13  [{'poll': 'Coaches Poll', 'ranks': [{'rank': 1...
# 8     2009    regular     9  [{'poll': 'Coaches Poll', 'ranks': [{'rank': 8...
# 9     2009    regular     7  [{'poll': 'Coaches Poll', 'ranks': [{'rank': 1...
# 10    2009    regular     5  [{'poll': 'Coaches Poll', 'ranks': [{'rank': 1...
# ...

# %%
df_poll['polls'][0][0]
# Out:
# {'poll': 'Coaches Poll',
#  'ranks': [{'rank': 22,
#    'school': 'Wisconsin',
#    'conference': 'Big Ten',
#    'firstPlaceVotes': 0,
#    'points': 247},
#   {'rank': 11,
#    'school': 'Iowa',
#    'conference': 'Big Ten',
#    'firstPlaceVotes': 0,
#    'points': 918},
#   {'rank': 8,
#    'school': 'Ohio State',
#    'conference': 'Big Ten',
#    'firstPlaceVotes': 0,
#    'points': 1077},
#   {'rank': 21,
#    'school': 'Stanford',
#    'conference': 'Pac-10',
#    'firstPlaceVotes': 0,
#    'points': 253},
#   {'rank': 23,
#    'school': 'Arizona',
#    'conference': 'Pac-10',
#    'firstPlaceVotes': 0,
#    'points': 237},
#   {'rank': 20,
#    'school': 'Oregon State',
#    'conference': 'Pac-10',
#    'firstPlaceVotes': 0,
#    'points': 368},
#   {'rank': 7,
#    'school': 'Oregon',
#    'conference': 'Pac-10',
#    'firstPlaceVotes': 0,
#    'points': 1096},
#   {'rank': 16,
#    'school': 'Pittsburgh',
#    'conference': 'Big East',
#    'firstPlaceVotes': 0,
# ...

# %%
pd.json_normalize(df_poll['polls'][0][0])['ranks'].explode().reset_index(drop=True)[0]['rank']
# Out:
# 22

# %% [markdown]
# &nbsp;

# %%
output_dir = r'C:\Users\RJ\OneDrive\education\mads\591_592\milestone\\
